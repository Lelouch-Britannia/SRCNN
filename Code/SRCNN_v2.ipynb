# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
import requests
import zipfile
import os

# Setup a data folder
data_path = "SRCNN"
image_path = os.path.join(data_path, "Data")

# If the image folder doesn't exist, download it and prepare it...
if os.path.exists(image_path):
    print(f"{image_path} directory already exists....skipping download")
else:
    print(f"{image_path} doesn't exist...creating one")
    os.makedirs(image_path)

# Download the data from GitHub
zip_file_path = os.path.join(data_path, "Data.zip")
github_url = "https://github.com/Lelouch-Britannia/SRCNN/raw/master/Data.zip"

with open(zip_file_path, "wb") as f:
    print("Downloading HR train and test images...")
    response = requests.get(github_url)
    f.write(response.content)

# Unzip data
with zipfile.ZipFile(zip_file_path, "r") as zip_ref:
    print("Unzipping HR train and test images.....")
    zip_ref.extractall(image_path)
# Out:
# SRCNN/Data doesn't exist...creating one
# Downloading HR train and test images...
# Unzipping HR train and test images.....

# %%
import numpy as np
import matplotlib.pyplot as plt
import pathlib as Path
import torch
import os

# %%
# Setup device agnostic code
device = "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cuda'

# %% [markdown]
# # 1.0 Image Quality Metrics
#
# 1. Mean Squared Error(MSE) :  MSE loss function is evaluated only by the difference between the central pixels of Xi and the network output.
#
# $$
# L(\Theta) = \frac{1}{n} \sum_{i=1}^n \left \| F(Y_i; \Theta) - X_i \right \|^2,
# $$
#
# where n is the number of training examples. Using MSE as the loss functiion favors a high PSNR.
#
# Alternative evaluation metrics,
#
# 1. Peak Signal To Noise Ratio(PSNR)
#
# 2. Structural Similarity Index(SSIM)

# %% [markdown]
# ## 1.1 Mean Squared Error(MSE)

# %%
import numpy as np

def mse(original : np.ndarray, target : np.ndarray) -> float:

  """
  Compute the Mean Squared Error (MSE) between two images.

  Parameters:
  original (np.ndarray): The original image, expected to be a numpy array.
  compressed (np.ndarray): The compressed or modified image, expected to be a numpy array.

  Returns:
  float: The MSE value.
  """

  original_data = original.astype(np.float64)
  target_data = target.astype(np.float64)

  mse = np.mean((original_data - target_data)**2)
  return mse

# %% [markdown]
# ## 1.2 Peak Signal To Noise Ratio(PSNR)

# %%
import numpy as np

def psnr(original : np.ndarray, target : np.ndarray) -> float:
  """
  Compute the Peak Signal to Noise Ratio (PSNR) between two images.

  Parameters:
  original (numpy.ndarray): The original image.
  compressed (numpy.ndarray): The compressed or modified image.

  Returns:
  float: The PSNR value in decibels (dB).
  """

  original_data = original.astype(np.float64)
  target_data = target.astype(np.float64)

  mse = np.mean((original_data - target_data)**2)
  if mse == 0:
    # MSE is zero means no noise is present in the signal.
    # Therefore, PSNR is infinite.
    return float('inf')

  max = 255.0
  psnr_val = 20*np.log10(max / np.sqrt(mse))
  return psnr_val

# %% [markdown]
# ## 1.4 Structural Similarity Index(SSIM)

# %%
from skimage.metrics import structural_similarity as ssim_lib
from skimage.color import rgb2gray
import numpy as np

def ssim(original : np.ndarray, target : np.ndarray) -> float:
  """
  Compute the Structural Similarity Index (SSIM) between two images.

  Parameters:
  original (np.ndarray): The original image.
  compressed (np.ndarray): The compressed or modified image.

  Returns:
  float: The SSIM value.
  """

  # Convert images to grayscale if they are in color because SSIM is often computed in grayscale
  if original.ndim == 3:
    original = rgb2gray(original)
  if target.ndim == 3:
    target = rgb2gray(target)

  ssim_value, _ = ssim_lib(original, target, full=True)
  return ssim_value

# %% [markdown]
# ## 1.3 Custom Peak Signal To Noise Ratio(PSNR)

# %%
import numpy as np

def custom_psnr(output, target) -> float:
    """
    Compute the Peak Signal to Noise Ratio (PSNR) focusing on the central region of the images.

    Parameters:
    output (torch.Tensor): The output from the model.
    target (torch.Tensor): The target high-resolution images.

    Returns:
    float: The computed PSNR value in decibels (dB).
    """

    # Calculate the difference in size between the target and the output
    delta_h = output.shape[0] - target.shape[0]
    delta_w = output.shape[1] - target.shape[1]

    # Calculate the start and end indices for cropping
    start_height = delta_h // 2
    end_height = start_height + target.shape[0]
    start_width = delta_w // 2
    end_width = start_width + target.shape[1]

    # Crop the central region of the target to match the output size
    output_cropped = output[start_height:end_height, start_width:end_width, :]

    # Compute MSE loss
    mse_loss = np.mean((output_cropped - target) ** 2)
    if mse_loss == 0:
        return float('inf')

    max_pixel = 1.0  # Assuming the tensors are scaled between 0 and 1
    psnr_val = 20 * np.log10(max_pixel / np.sqrt(mse_loss))

    return psnr_val.item()

# %% [markdown]
# ## 1.5 Custom MSE

# %%
import numpy as np

def custom_mse_loss(output, target):
    """
    Compute the Mean Squared Error (MSE) focusing on the central region of the images.

    Parameters:
    output (torch.Tensor): The output from the model.
    target (torch.Tensor): The target high-resolution images.

    Returns:
    torch.Tensor: The computed MSE loss.
    """
    # Assuming output and target are both 4D tensors of shape [batch_size, channels, height, width]
    # First, we need to calculate the central region of the target to match the output size

    # Calculate the difference in size between the target and the output
    delta_h = output.shape[0] - target.shape[0]
    delta_w = output.shape[1] - target.shape[1]

    # Calculate the start and end indices for cropping
    start_height = delta_h // 2
    end_height = start_height + target.shape[0]
    start_width = delta_w // 2
    end_width = start_width + target.shape[1]

    # Crop the central region of the target to match the output size
    output_cropped = output[start_height:end_height, start_width:end_width, :]

    # Compute MSE loss
    mse_loss = np.mean((output_cropped - target) ** 2)

    return mse_loss

# %% [markdown]
# ## 1.6 Combined Metric

# %%
from typing import Tuple
import numpy as np

def combined_metric(original : np.ndarray, target : np.ndarray) -> Tuple:
  """
  Combined metric using MSE, PSNR and SSIM

  Parameters:
  original (np.ndarray): The original image.
  compressed (np.ndarray): The compressed or modified image.

  Return:
  Tuple: (MSE, PSNR, SSIM)
  """

  mse_val = mse(original, target)
  psnr_val = psnr(original, target)
  ssim_val = ssim(original, target)

  return (mse_val, psnr_val, ssim_val)

# %% [markdown]
# # 2.0 Becoming one with the data(Pre Process and Explore)

# %%
def walk_through_dir(path : str) -> None:
  """
  Walk through Directory returning its content
  """

  for dirpath, dirname, filenames in os.walk(path):
    print(f"There are {len(filenames)} images in the {dirpath}")

# %%
image_path = 'SRCNN/Data/Train'
walk_through_dir(image_path)
# Out:
# There are 0 images in the SRCNN/Data/Train
# There are 91 images in the SRCNN/Data/Train/HR

# %% [markdown]
# ## 2.1 Visualizing the data
#
# 1. Get all the image paths
# 2. Pick a random image using `np.random.randint()`
# 3. Since we're working with images, let's open image with matplotlib
# 4. Show Image with Metadata

# %%
from PIL import Image
from pathlib import Path

# np.random.seed(42)

# Get posix path
image_path = 'SRCNN/Data/Train'
image_path = Path(os.path.join(image_path, "HR"))

# 1. Get all the image path
image_path = list(image_path.glob("*.bmp"))

# 2. Pick a radom image path
idx = np.random.randint(0, len(image_path))
random_img_path = image_path[idx]

# 3. Open Image
# random_img = plt.imread(random_img_path)
random_img = Image.open(random_img_path).convert('RGB')
random_img = np.array(random_img)

# Plot using matplotlib
plt.figure(figsize=(6,4))
plt.imshow(random_img)
plt.title(f"Image Shape: {random_img.shape}", fontsize=10) # shape: [height, width, color_chnanel]
plt.axis("off")
plt.show()

# %% [markdown]
# # 3.0 Transforming Data
#
# To prepare our dataset for training a Super-Resolution CNN (SRCNN), we need to simulate low-resolution (LR) images from our high-resolution (HR) images. The following steps are taken for each image in our HR dataset:
#
# 1. **Apply Gaussian Blur**:
#    A Gaussian blur is applied to the HR images. This step is performed to smooth out the images and simulate the loss of detail that occurs in a real-world low-resolution image.
#
# 2. **Downscale**:
#    The blurred HR images are then downsampled by a specified upscale factor.
#
# 3. **Upscale**:
#    The downsampled images are then upscaled back to the original dimensions using bicubic interpolation.
#
# 4. **Save Processed Images**:
#   The processed LR images are saved back to the filesystem for use in training the SRCNN.

# %% [markdown]
# ## 3.0.1 LR Transformations

# %%
# Hyperparameters for Gaussian Blur
kernel_size = (5, 5)
sigma = 0.5
scale = 3

# %%
import cv2 as cv
import numpy as np
from typing import Tuple

def generate_lr_image(image: np.ndarray, operation: str, scale: int, kernel_size: Tuple[int, int] = (5, 5), sigma: float = 0) -> np.ndarray:
  """
  Processes the low-resolution image based on the specified operation: Gaussian Blur, Down-and-Up sampling, or both,
  for both grayscale and color images.

  Parameters:
  - image (np.ndarray): The input image to process. Can be grayscale or color.
  - operation (str): The operation to perform - 'blur', 'downup', 'both'.
  - scale (int): The downscaling factor for down-and-up sampling.
  - kernel_size (Tuple[int, int]): The kernel size for Gaussian blur.
  - sigma (float): The sigma value for Gaussian blur.

  Returns:
  - np.ndarray: Low-resolution image.
  """
  # Check if the image is grayscale or color
  if len(image.shape) == 2:
    # Grayscale image
    h, w = image.shape
  else:
    # Color image
    h, w, _ = image.shape

  lr_image = image

  if operation in ['blur', 'both']:
    # Apply Gaussian Blur
    lr_image = cv.GaussianBlur(lr_image, kernel_size, sigma)

  if operation in ['downup', 'both']:
    # Downscale and then upscale
    if len(image.shape) == 2:
      # Grayscale
      lr_image = cv.resize(cv.resize(lr_image, (w // scale, h // scale), interpolation=cv.INTER_CUBIC), (w, h), interpolation=cv.INTER_CUBIC)
    else:
      # Color
      lr_image = cv.resize(cv.resize(lr_image, (w // scale, h // scale), interpolation=cv.INTER_CUBIC), (w, h), interpolation=cv.INTER_CUBIC)

  return lr_image

# %%
operation = input("Enter the operation that needs to performed on HR Image: ")

# Print message about the processing type
if operation == 'blur':
    print(f"Applying Gaussian Blur with kernel size {kernel_size} and sigma {sigma}.")
elif operation == 'downup':
    print("Applying Down-and-Up sampling.")
elif operation == 'both':
    print(f"Applying both Gaussian Blur with kernel size {kernel_size} and sigma {sigma}, and Down-and-Up sampling.")
# Out:
# Enter the operation that needs to performed on HR Image: downup
# Applying Down-and-Up sampling.

# %%
# Setup train Paths
image_path = 'SRCNN/Data/Train'
hr_train_path = os.path.join(str(image_path), "HR")
lr_train_path = os.path.join(str(image_path), "LR")
hr_train_path, lr_train_path
# Out:
# ('SRCNN/Data/Train/HR', 'SRCNN/Data/Train/LR')

# %%
# Setup test Paths
test_image_path = 'SRCNN/Data/Test'
hr_test_path = os.path.join(str(test_image_path), "HR")
lr_test_path = os.path.join(str(test_image_path), "LR")
hr_test_path, lr_test_path
# Out:
# ('SRCNN/Data/Test/HR', 'SRCNN/Data/Test/LR')

# %%
from PIL import Image

def plot_hr_lr_images(hr_img_dir: str, n: int = 3, seed=52):
  if seed:
    np.random.seed(seed)

  plt.figure(figsize=(10, 10))

  random_idx_list = list(np.random.randint(0, len(os.listdir(hr_img_dir)), n))

  for i, idx in enumerate(random_idx_list):
    hr_img_path = os.path.join(hr_img_dir, os.listdir(hr_img_dir)[idx])
    # lr_img_path = os.path.join(lr_img_dir, os.listdir(lr_img_dir)[idx])

    # hr_img = plt.imread(hr_img_path)
    # lr_img = plt.imread(lr_img_path)

    hr_img = Image.open(hr_img_path).convert('RGB')
    # lr_img = Image.open(lr_img_path).convert('RGB')

    hr_img = np.array(hr_img)
    # lr_img = np.array(lr_img)
    lr_img = generate_lr_image(hr_img, operation, scale, kernel_size, sigma)

    # Calculate the combined metrics
    metrics = combined_metric(hr_img, lr_img)
    metrics_str = f"MSE: {metrics[0]:.2f}\n PSNR: {metrics[1]:.2f} dB\n SSIM: {metrics[2]:.2f}\n"

    plt.subplot(n, 2, 2 * i + 1)
    plt.imshow(hr_img)
    plt.title(f"HR Image\nSize: {hr_img.shape}", fontsize=8)
    plt.xticks([])
    plt.yticks([])

    plt.subplot(n, 2, 2 * i + 2)
    plt.imshow(lr_img)
    plt.title(f"LR Image\nSize: {lr_img.shape}", fontsize=8)
    plt.xlabel(metrics_str, fontsize=8)  # Display combined metrics here
    plt.xticks([])
    plt.yticks([])
    # plt.axis("off")

  plt.tight_layout()
  plt.show()

# %%
plot_hr_lr_images(hr_img_dir = hr_train_path,
                  n = 3)

# %% [markdown]
# ## 3.1 Architecture

# %%
arch_input = input("Enter the SRCNN architecture as comma-separated filter sizes (e.g., '9,1,5'): ")
arch = [int(x.strip()) for x in arch_input.split(',')]
# Out:
# Enter the SRCNN architecture as comma-separated filter sizes (e.g., '9,1,5'): 9,3,5

# %% [markdown]
# ## 3.2 Modcrop

# %%
def modcrop(img, modulo):

  if img.ndim == 2:
    sz = img.shape
    sz = sz - np.mod(sz, modulo)
    img_cropped = img[0:sz[0], 0:sz[1]]
  elif img.ndim == 3:
    sz = img.shape[0:2]
    sz = sz - np.mod(sz, modulo)
    img_cropped = img[0:sz[0], 0:sz[1], :]
  else:
    raise ValueError("Unsupported image dimensions")

  return img_cropped

# %% [markdown]
# ## 3.3 Sub Images using different blurring options(From Authors)

# %%
import os
import sys
import cv2 as cv
import numpy as np
import argparse
from PIL import Image
from typing import Tuple

def generate_patches(filepath: str, patches_label_dir: str, patches_data_dir: str, operation: str, kernel_size: Tuple[int, int] = (5, 5), sigma: float = 0, size_input:int = 33, size_label:int = 21, scale:int = 3, stride:int = 14):
  """
  Generates training patches from a single image file and saves them to specified directories.

  This function takes an image file, processes it to generate low-resolution (LR) and high-resolution (HR) patches, and saves these patches as individual image files in specified directories. LR patches are generated by downsampling and then upsizing the original HR image using bicubic interpolation. The function then extracts patches of specified sizes from both the LR and HR images using a specified stride.

  Parameters:
  - filename (str): Path to the original HR image file.
  - patches_label_dir (str): Directory path where HR (label) patches will be saved.
  - patches_data_dir (str): Directory path where LR (input/data) patches will be saved.
  - size_input (int, optional): Size of the LR patches. Default is 33.
  - size_label (int, optional): Size of the HR patches. Default is 21.
  - scale (int, optional): Factor by which the HR image is downsampled to generate the LR image. Default is 3.
  - stride (int, optional): Stride with which patches are extracted from the images, controlling the overlap. Default is 14.

  Returns:
  - int: The total number of patches generated from the image.

  Raises:
  - TypeError: If the input image is not a PIL Image object.
  """
  # Create directories for patches if they don't exist
  os.makedirs(patches_label_dir, exist_ok=True)
  os.makedirs(patches_data_dir, exist_ok=True)

  filename = os.path.basename(filepath).split('.')[0]

  padding = (size_input - size_label) // 2

  img = Image.open(filepath).convert('RGB')

  if not isinstance(img, Image.Image):
    raise TypeError('img should be PIL Image. Got {}'.format(type(img)))

  img_ycbcr = img.convert('YCbCr')

  # Convert images to numpy arrays
  img = np.array(img_ycbcr)

  # Take the y channel
  y_channel = img[:, :, 0]

  im_label = modcrop(y_channel, scale)
  h, w = im_label.shape
  total_patches = 0

  # Process the image for low-resolution version
  im_input = generate_lr_image(im_label, operation, scale, kernel_size, sigma)

  # Save each patch to the respective directories
  for x in range(0, h-size_input+1, stride):
    for y in range(0,  w-size_input+1, stride):
      # Extract the data and label patch
      data_patch = im_input[x:x+size_input, y:y+size_input]
      label_patch = im_label[x+padding:x+padding+size_label, y+padding:y+padding+size_label]

      # Convert patches back to images
      data_patch_img = Image.fromarray(data_patch)
      label_patch_img = Image.fromarray(label_patch)

      total_patches += 1

      # Save the patch
      data_patch_img.save(os.path.join(patches_data_dir, f'{filename}_{x}_{y}.png'))
      label_patch_img.save(os.path.join(patches_label_dir, f'{filename}_{x}_{y}.png'))

  return total_patches

# %%
# Generating training data

train_data_dir = "SRCNN/Data/Train/HR"
size_input = 33
size_label = size_input - sum([f - 1 for f in arch])
stride = 14

total = 0
for filename in os.listdir(train_data_dir):
  filepath = os.path.join(train_data_dir, filename)
  if os.path.isfile(filepath):
    patches_count = generate_patches(filepath=filepath,
            patches_label_dir='SRCNN/Data/Train/pHR',
            patches_data_dir='SRCNN/Data/Train/pLR',
            operation=operation,
            kernel_size=kernel_size,
            sigma=sigma,
            size_input=size_input,
            size_label=size_label,
            scale=scale,
            stride=stride)
    total += patches_count
    print(f'Generated {patches_count} patches from {filename}')

print(f'Total patches generated: {total}')

# %%
# Generating Validation data

validation_data_dir = "SRCNN/Data/Test/HR"
size_input = 33
size_label = size_input - sum([f - 1 for f in arch])
stride = 21

total = 0
for filename in os.listdir(validation_data_dir):
  filepath = os.path.join(validation_data_dir, filename)
  if os.path.isfile(filepath):
    patches_count = generate_patches(filepath=filepath,
            patches_label_dir='SRCNN/Data/Validation/pHR',
            patches_data_dir='SRCNN/Data/Validation/pLR',
            operation=operation,
            kernel_size=kernel_size,
            sigma=sigma,
            size_input=size_input,
            size_label=size_label,
            scale=scale,
            stride=stride)
    total += patches_count
    print(f'Generated {patches_count} patches from {filename}')

print(f'Total patches generated: {total}')

# %% [markdown]
# ## 3.4 Plot image and patches

# %%
# %%capture
# !pip install patchify

# %%
import numpy as np
from PIL import Image
from patchify import patchify
import matplotlib.pyplot as plt

def plot_image_with_all_patches(img_path: str, patch_size: tuple, step: int) -> None:
  """
  Generates patches for an image using patchify and plots them alongside the original image.

  Parameters:
  img_path (str): Path to the image file.
  patch_size (tuple): The size of the patches (width, height).
  step (int): The step size for the sliding window when patchifying.
  """
  # Load the image
  img = Image.open(img_path)
  img_array = np.array(img)

  # Generate patches
  patches = patchify(img_array, patch_size + (3,), step=step)

  # Calculate the layout for plotting
  num_patches = patches.shape[0] * patches.shape[1]
  num_columns = patches.shape[1]
  num_rows = patches.shape[0]

  # Plot the original image
  plt.figure(figsize=(5, 5))
  plt.imshow(img)
  plt.title(f"Size: {img_array.shape}", fontsize=8)
  plt.axis('off')
  # plt.show()

  # Create a new figure for patches
  fig, axes = plt.subplots(num_rows, num_columns, figsize=(5, 5))

  # Ensure we have a 2D axes array for single row/column
  if num_rows == 1 or num_columns == 1:
    axes = np.array(axes).reshape(num_rows, num_columns)

  # Plot each patch
  for i in range(num_rows):
    for j in range(num_columns):
        patch_img = patches[i, j, 0]
        axes[i, j].imshow(patch_img)
        axes[i, j].axis('off')

  # Adjust the spacing
  plt.subplots_adjust(wspace=0.1, hspace=0.05)
  # Alternatively, you can use tight_layout with parameters
  # plt.tight_layout(pad=1.0, w_pad=0.5, h_pad=0.5)

  plt.show()

# %%
np.random.seed(42)

hr_img_paths = list(os.listdir(hr_train_path))
patch_size = (33, 33)

# Select random index and plot image along with patches
idx = int(np.random.randint(0, len(hr_img_paths), 1))
random_img_path = os.path.join(hr_train_path, hr_img_paths[idx])

plot_image_with_all_patches(random_img_path, patch_size, stride)
# Out:
# <ipython-input-28-1c9e83e4d257>:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   idx = int(np.random.randint(0, len(hr_img_paths), 1))

# %% [markdown]
# # 4.0 Loading Images data with custom 'Dataset'
#
# To create our own custom dataset, we want to:
#
# 1. Subclass `torch.utils.data.Dataset`
# 2. Init our subclass with a target directories(the directory we'd like to get data from) as well as a transfrom if we'd like to transform out data
# 3. Create several attribute:
#   * lr and hr path of our images
#   * tranform - The transfrom we'd like to use
# 4. Create a function to `load_image()`, this function will open the image
# 5. Overwrite the `__len()__` method to return the length of our dataset
# 6. Overwrite the `__getitem()__` method to return a given sample when passed an index

# %% [markdown]
# ### 4.0.1 Transform for No Blurring(From Author)

# %%
import torch
from torch.utils.data import Dataset
from torchvision.transforms import Compose, ToTensor
from pathlib import Path
from PIL import Image
from typing import Tuple, Dict, List

class SRCNN(Dataset):

  # 2. Initialize with a lr/hr_img_dir and transform(optional) parameter
  def __init__(self, lr_img_dir : str, hr_img_dir : str, ext : str,transform = None):

    # 3. Create class attributes
    self.img_paths = sorted(list(Path(lr_img_dir).glob(f"*.{ext}")))
    self.label_paths = sorted(list(Path(hr_img_dir).glob(f"*.{ext}")))

    # Setup transform
    self.transform = transform


  # Make function to load images
  def load_target(self, idx : int) -> Image.Image:

    """Opens an image via file path and returns it"""
    target_path = self.img_paths[idx]
    return Image.open(target_path)

  def load_label(self, idx : int) -> Image.Image:

    """Opens an image via file path and returns it"""
    label_path = self.label_paths[idx]
    return Image.open(label_path)

  # Overwrite the __len()__ method
  def __len__(self)-> int:

    "Returns the total number of samples."
    return len(self.img_paths)

  def __getitem__(self, idx : int) -> Tuple[torch.tensor, torch.tensor]:

    """Returns one sample of data, data and label (X, y)"""
    img = self.load_target(idx)
    target = self.load_label(idx)

    # Transform if necessary
    if self.transform:
      img = self.transform(img)
      target = self.transform(target)

    return img, target # return data, label (X, y)

# %%
def rgb_to_ycrcb(img: Image.Image) -> Image.Image:
    """
    Convert an RGB image to YCrCb and extract the Y channel.
    """
    if not isinstance(img, Image.Image):
        raise TypeError('img should be PIL Image. Got {}'.format(type(img)))

    ycrcb_img = img.convert('YCbCr')
    y, _, _ = ycrcb_img.split()
    return y

# %%
from torchvision import transforms
# Augment train data
train_transform = transforms.Compose([
    # transforms.RandomHorizontalFlip(p=0.5),
    transforms.ToTensor()
])

validation_transform = transforms.Compose([
    transforms.ToTensor()
])

test_transform = transforms.Compose([
    rgb_to_ycrcb,
    transforms.ToTensor()
])

# %%
train_imgs = 'SRCNN/Data/Train/pLR'
train_labels = 'SRCNN/Data/Train/pHR'

val_imgs = 'SRCNN/Data/Validation/pLR'
val_labels = 'SRCNN/Data/Validation/pHR'

# test_imgs = 'SRCNN/Data/Test/LR'
# test_labels = 'SRCNN/Data/Test/HR'

train_data_custom = SRCNN(lr_img_dir = train_imgs,
                          hr_img_dir = train_labels,
                          ext = "png",
                          transform = train_transform)

validation_data_custom = SRCNN(lr_img_dir = val_imgs,
                          hr_img_dir = val_labels,
                          ext = "png",
                          transform = validation_transform)

# test_data_custom = SRCNN(lr_img_dir = test_imgs,
#                          hr_img_dir = test_labels,
#                          ext = "bmp",
#                          transform = test_transform)

train_data_custom, validation_data_custom
# Out:
# (<__main__.SRCNN at 0x78c07b0fe3b0>, <__main__.SRCNN at 0x78c07b0feb90>)

# %%
print(f"Length of Training Data: {len(train_data_custom)}")
print(f"Length of Training Data: {len(validation_data_custom)}")
# print(f"Length of Test Data: {len(test_data_custom)}")
# Out:
# Length of Training Data: 21884
# Length of Training Data: 7731

# %% [markdown]
# ## 4.1 Turn custom loaded images into DataLoader's

# %% [markdown]
# ### 4.1.1 Collate function

# %%
import torch
from torch.nn.functional import pad

def custom_collate_fn(batch):


  # Find the largest image size in the batch
  max_height = max([item[0].size(1) for item in batch])
  max_width = max([item[0].size(2) for item in batch])

  batch_imgs = []
  batch_labels = []

  for(img, label) in batch:
    # Calculate padding size
    height_pad = max_height - img.size(1)
    width_pad = max_width - img.size(2)

    # Pad the image and label tensors to have the same size
    # Adjust padding as needed for your dataset (e.g., you might want symmetric padding)
    img_padded = pad(img, (0, width_pad, 0, height_pad))
    label_padded = pad(label, (0, width_pad, 0, height_pad))

    batch_imgs.append(img_padded)
    batch_labels.append(label_padded)

  # Stack all images and labels to form a batch
  batch_imgs = torch.stack(batch_imgs)
  batch_labels = torch.stack(batch_labels)


  return batch_imgs, batch_labels

# %%
import os
from torch.utils.data import DataLoader, random_split

BATCH_SIZE = 64

# Split the validation dataset(Too big validation)
validation_size = int(1.0 * len(validation_data_custom))  # 50% for validation
rest_validation_size = len(validation_data_custom) - validation_size
validation_dataset = random_split(validation_data_custom, [rest_validation_size, validation_size])

# training_size = len(train_data_custom) - validation_size  # Remaining for training
# train_dataset, validation_dataset = random_split(train_data_custom, [training_size, validation_size])

# Create dataloaders for each set
train_dataloader_custom = DataLoader(dataset=train_data_custom,
                                     num_workers=os.cpu_count(),
                                     batch_size=BATCH_SIZE,
                                     shuffle=True)

validation_dataloader_custom = DataLoader(dataset=validation_data_custom,
                                          num_workers=os.cpu_count(),
                                          batch_size=BATCH_SIZE,
                                          shuffle=False)

# test_dataloader_custom = DataLoader(dataset=test_data_custom,
#                                     num_workers=os.cpu_count(),
#                                     batch_size=BATCH_SIZE,
#                                     shuffle=False,
#                                     collate_fn=custom_collate_fn)  # Use the custom collate function

train_dataloader_custom, validation_dataloader_custom
# Out:
# (<torch.utils.data.dataloader.DataLoader at 0x78c07b0ff250>,
#  <torch.utils.data.dataloader.DataLoader at 0x78c07b0ff640>)

# %%
# Get first batch of image and label from custom dataloader
img_custom, label_custom = next(iter(train_dataloader_custom))

# print out shape
print(f"Image Batch shape: {img_custom.shape} ->[batch_size, color_channel, height, width]")
print(f"Label Shape: {label_custom.shape}")
# Out:
# Image Batch shape: torch.Size([64, 1, 33, 33]) ->[batch_size, color_channel, height, width]
# Label Shape: torch.Size([64, 1, 19, 19])

# %% [markdown]
# ## 4.2 Create a function to display random images
#
# 1. Take `Dataset` and `n` number of images to display
# 2. To prevent display getting out of hand, we'll cap `n` to 10 iamges
# 3. Set the random seed
# 4. Get a list of random indexes for plotting
# 5. Setup `matplotlib` plot
# 6. Loop through random list of index found in Step : 4  and plot them with `matplotlib`
# 7. Make sure the images are of right shape before we plot them.

# %%
def display_random_images(dataset: torch.utils.data.dataset.Dataset,
                          n: int = 5,
                          display_shape: bool = True,
                          seed: int = None):

  # 2. Adjust display if n is high
  if n > 5:
    n = 10
    display_shape = False
    print(f"For display purposes, n shouldn't be larger than 10, setting to 10 and removing shape display")


  if seed:
    torch.manual_seed(seed)

  # 3. Get random sample of indexes
  random_samples_idx = torch.randint(0, len(dataset), size=([1, n])).tolist()[0]

  # 4. Setup plot
  plt.figure(figsize=(6,18))

  # 5. Loop through samples and display random samples
  for i, targ_sample in enumerate(random_samples_idx):
    targ_img, targ_label = dataset[targ_sample]

    # 6. Adjust image tensor shape for plotting: [color_channels, height, width] -> [height, width, color_channel]
    targ_img = targ_img.permute(1, 2, 0)
    targ_label = targ_label.permute(1, 2, 0)

    # Plot adjusted samples
    plt.subplot(n, 2, 2*i+1)
    plt.imshow(targ_img, cmap="gray")
    if display_shape:
      plt.title(f"LR Image\nSize: {targ_img.shape}", fontsize = 8)
      mse_val = custom_mse_loss(targ_img.numpy(), targ_label.numpy())
      psnr_val = custom_psnr(targ_img.numpy(), targ_label.numpy())
      metrics_str = f"MSE: {mse_val:.2f}\n PSNR: {psnr_val:.2f} dB\n"
      plt.xlabel(metrics_str, fontsize=8)
    plt.xticks([])
    plt.yticks([])

    plt.subplot(n, 2, 2*i+2)
    plt.imshow(targ_label, cmap="gray")
    if display_shape:
      plt.title(f"HR Image\nSize: {targ_label.shape}", fontsize = 8)
    plt.xticks([])
    plt.yticks([])

# %%
# Display random images from custom created Dataset
display_random_images(dataset=train_data_custom,
                      n=5,
                      seed=None)

# %% [markdown]
# # 5.0 Model : SRCNN w/o Data Augmentation
#
# Let's replicate SRCNN architecture from paper https://arxiv.org/pdf/1501.00092.pdf

# %% [markdown]
# ## 5.1 SRCNN Model(9-x-5) Class

# %%
# Setup device agnostic code
device = "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cuda'

# %%
import torch
import torch.nn as nn
import torch.nn.init as init

class SRCNNModel(nn.Module):

  """
  Model architecture(9-3-5) from original paper
  """

  def __init__(self, input_shape: int,
               hidden_units_1: int,
               hidden_units_2: int,
               kernel_sizes: list,
               output_shape: int) -> None:

    super().__init__()

    self.conv_block_1 = nn.Sequential(
        nn.Conv2d(in_channels=input_shape,
                  out_channels=hidden_units_1,
                  kernel_size=kernel_sizes[0],
                  padding=0), # options = "valid" (no padding) or "same" (output has same shape as input) or int for specific number
        nn.ReLU(),
        nn.Conv2d(in_channels=hidden_units_1,
                  out_channels=hidden_units_2,
                  kernel_size=kernel_sizes[1],
                  padding=0), # options = "valid" (no padding) or "same" (output has same shape as input) or int for specific number
        nn.ReLU()
    )

    self.conv_block_2 = nn.Sequential(
        nn.Conv2d(in_channels=hidden_units_2,
                  out_channels=output_shape,
                  kernel_size=kernel_sizes[2],
                  padding=0)
    )
    self._intialize_weights()


  def _intialize_weights(self):

    for layer in self.modules():
      if isinstance (layer, nn.Conv2d):
        init.normal_(layer.weight, mean=0.0, std=0.001)
        if layer.bias is not None:
          init.zeros_(layer.bias)

  def forward(self, x):
    x = self.conv_block_1(x)
    # print(x.shape)
    x = self.conv_block_2(x)
    # print(x.shape)
    return x

# %% [markdown]
# ### 5.1.1 Sample Model(9-x-5)

# %%
torch.manual_seed(42)
model_0 = SRCNNModel(input_shape=1,
                   hidden_units_1=64,
                   hidden_units_2=32,
                   kernel_sizes=arch,
                   output_shape=1).to(device)

model_0
# Out:
# SRCNNModel(
#   (conv_block_1): Sequential(
#     (0): Conv2d(1, 64, kernel_size=(9, 9), stride=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1))
#     (3): ReLU()
#   )
#   (conv_block_2): Sequential(
#     (0): Conv2d(32, 1, kernel_size=(5, 5), stride=(1, 1))
#   )
# )

# %% [markdown]
# ## 5.2 Try a forward pass on a single image(to test the model)

# %%
# Get a single batch of images
img_batch, label_batch = next(iter(train_dataloader_custom))
img_batch.shape, label_batch.shape
# Out:
# (torch.Size([64, 1, 33, 33]), torch.Size([64, 1, 19, 19]))

# %%
# Try a forward pass
model_0(img_batch.to(device))

# %% [markdown]
# ## 5.3 Use `torchinfo` to get an idea of the shapes going through our model

# %%
try:
  import torchinfo
except:
  # !pip install torchinfo
  import torchinfo

from torchinfo import summary
summary(model_0, input_size=[1, 1, 33, 33])
# Out:
# Collecting torchinfo
#   Downloading torchinfo-1.8.0-py3-none-any.whl (23 kB)
# Installing collected packages: torchinfo
# Successfully installed torchinfo-1.8.0
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# SRCNNModel                               [1, 1, 19, 19]            --
# ├─Sequential: 1-1                        [1, 32, 23, 23]           --
# │    └─Conv2d: 2-1                       [1, 64, 25, 25]           5,248
# │    └─ReLU: 2-2                         [1, 64, 25, 25]           --
# │    └─Conv2d: 2-3                       [1, 32, 23, 23]           18,464
# │    └─ReLU: 2-4                         [1, 32, 23, 23]           --
# ├─Sequential: 1-2                        [1, 1, 19, 19]            --
# │    └─Conv2d: 2-5                       [1, 1, 19, 19]            801
# ==========================================================================================
# Total params: 24,513
# Trainable params: 24,513
# Non-trainable params: 0
# Total mult-adds (M): 13.34
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.46
# Params size (MB): 0.10
# Estimated Total Size (MB): 0.56
# ==========================================================================================

# %% [markdown]
# ## 5.4 Create train and test loop function
#
# * `train_step()` - Takes in model and dataloader and trains the model on the dataloader
#
# * `test_step()` - Take in model and dataloader and evaluatest the model on the dataloader

# %%
import torch

def train_step(model: torch.nn.Module,
               dataloader: torch.utils.data.DataLoader,
               loss_fn,
               optimizer: torch.optim.Optimizer,
               device: str,
               max_pixel_value: float = 1.0) -> (float, float):
    """
    Performs a single training step including forward pass, loss computation,
    backpropagation, and optimizer step.

    Parameters:
    - model (torch.nn.Module): The neural network model to be trained.
    - dataloader (torch.utils.data.DataLoader): DataLoader for the dataset.
    - loss_fn: Loss function used for training.
    - optimizer (torch.optim.Optimizer): Optimizer used for parameter updates.
    - device (str): Device to run the training on ('cuda' or 'cpu').
    - max_pixel_value (float, optional): The maximum pixel value used in the PSNR calculation. Default is 1.0.

    Returns:
    - train_loss (float): Average training loss for this step.
    - train_psnr (float): Average Peak Signal-to-Noise Ratio (PSNR) for this step.

    Raises:
    - ValueError: If `device` is not 'cuda' or 'cpu'.
    - TypeError: If the provided model, dataloader, loss function, or optimizer are of the wrong type.
    """

    # Validate input parameters for type and value
    if not isinstance(model, torch.nn.Module):
        raise TypeError("model must be an instance of torch.nn.Module")
    if not isinstance(dataloader, torch.utils.data.DataLoader):
        raise TypeError("dataloader must be an instance of torch.utils.data.DataLoader")
    if not callable(loss_fn):
        raise TypeError("loss_fn must be callable")
    if not isinstance(optimizer, torch.optim.Optimizer):
        raise TypeError("optimizer must be an instance of torch.optim.Optimizer")
    if device not in ['cuda', 'cpu']:
        raise ValueError("device must be 'cuda' or 'cpu'")

    # Ensure model is on the correct device
    model.to(device)

    # Put the model in train mode
    model.train()

    # Setup train loss and PSNR
    train_loss = 0.0
    train_psnr = 0.0

    # Loop through batches of data
    for _, (X, y) in enumerate(dataloader):
        X, y = X.to(device), y.to(device)

        # Forward pass
        y_pred = model(X)

        # Calculate loss
        loss = loss_fn(y_pred, y)
        train_loss += loss.item()

        # Zero gradients, perform a backward pass, and update the weights.
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # Calculate and accumulate PSNR
        psnr = 20 * torch.log10(max_pixel_value / torch.sqrt(loss.detach()))
        train_psnr += psnr.item()

    # Adjust metrics to get average loss and PSNR per batch
    train_loss /= len(dataloader)
    train_psnr /= len(dataloader)

    return train_loss, train_psnr

# %%
import torch

def test_step(model: torch.nn.Module,
              dataloader: torch.utils.data.DataLoader,
              loss_fn,
              device: str,
              max_pixel_value: float = 1.0) -> (float, float):
    """
    Performs a single evaluation step, calculating the average loss and PSNR
    over the provided dataloader.

    Parameters:
    - model (torch.nn.Module): The neural network model to be evaluated.
    - dataloader (torch.utils.data.DataLoader): DataLoader for the dataset to evaluate.
    - loss_fn: The loss function used for evaluation.
    - device (str): The device to run the evaluation on ('cuda' or 'cpu').
    - max_pixel_value (float, optional): The maximum pixel value used in the PSNR calculation. Default is 1.0.

    Returns:
    - test_loss (float): The average loss over the dataloader.
    - test_psnr (float): The average Peak Signal-to-Noise Ratio over the dataloader.

    Raises:
    - ValueError: If `device` is not 'cuda' or 'cpu'.
    - TypeError: If the provided model, dataloader, loss function, or device are of the wrong type.
    """

    # Validate input parameters
    if not isinstance(model, torch.nn.Module):
        raise TypeError("model must be an instance of torch.nn.Module")
    if not isinstance(dataloader, torch.utils.data.DataLoader):
        raise TypeError("dataloader must be an instance of torch.utils.data.DataLoader")
    if not callable(loss_fn):
        raise TypeError("loss_fn must be callable")
    if device not in ['cuda', 'cpu']:
        raise ValueError("device must be 'cuda' or 'cpu'")

    # Ensure model is on the correct device
    model.to(device)

    # Put the model in eval mode
    model.eval()

    test_loss = 0.0
    test_psnr = 0.0

    with torch.inference_mode():
        for _, (X, y) in enumerate(dataloader):
            X, y = X.to(device), y.to(device)

            # Forward pass
            test_pred = model(X)

            # Calculate loss
            loss = loss_fn(test_pred, y)
            test_loss += loss.item()

            # Calculate PSNR
            psnr = 20 * torch.log10(max_pixel_value / torch.sqrt(loss.detach()))
            test_psnr += psnr.item()

    # Compute average loss and PSNR
    test_loss /= len(dataloader)
    test_psnr /= len(dataloader)

    return test_loss, test_psnr

# %% [markdown]
# ## 5.5 Checkpoint Saving Function

# %%
import torch
import os

def save_checkpoint(epoch, model, optimizer, loss, path="checkpoint.pth"):
    """
    Saves a checkpoint of the model and optimizer state.

    Parameters:
    - epoch: The current epoch number.
    - model: The model being trained.
    - optimizer: The optimizer being used for training.
    - loss: The loss value at the checkpoint.
    - path: The path to save the checkpoint to.
    """
    checkpoint = {
        'epoch': epoch + 1,  # Saving such that training can resume from the next epoch
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
        'loss': loss,
    }
    torch.save(checkpoint, path)
    print(f"Checkpoint saved at '{path}'")

# %% [markdown]
# ## 5.6 Early Stopping and Best Model Saving

# %%
class EarlyStopping:

  def __init__(self, patience=7, verbose=False, delta=0, path='best_model.pth'):
    self.patience = patience
    self.verbose = verbose
    self.delta = delta
    self.best_score = None
    self.early_stop = False
    self.val_loss_min = np.Inf
    self.counter = 0
    self.path = path

  def __call__(self, val_loss, model, optimizer):
    score = -val_loss

    if self.best_score is None:
      self.best_score = score
      self.save_checkpoint(val_loss, model, optimizer)
    elif score < self.best_score + self.delta:
      self.counter += 1
      if self.verbose:
          print(f'EarlyStopping counter: {self.counter} out of {self.patience}')
      if self.counter >= self.patience:
          self.early_stop = True
    else:
      self.best_score = score
      self.save_checkpoint(val_loss, model, optimizer)
      self.counter = 0

  def save_checkpoint(self, val_loss, model, optimizer):
    '''Saves model when validation loss decrease.'''
    if self.verbose:
      print(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}).  Saving model ...')
    torch.save({
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
        'loss': val_loss,
    }, self.path)
    self.val_loss_min = val_loss

# %% [markdown]
# ## 5.7 Creating a `train()` function to combine `train_step()` and `test_step()`

# %%
import os
import time
from tqdm.auto import tqdm

# 1. Create a train function that takes in various model parameters
def train(model: torch.nn.Module,
          train_dataloader: torch.utils.data.DataLoader,
          test_dataloader: torch.utils.data.DataLoader,
          optimizer: torch.optim.Optimizer,
          loss_fn,
          path: str,
          start_epoch: int = 0,
          end_epoch: int = 200,
          checkpoint_interval=20,
          device: str = device):

  # Start the timer
  start_time = time.time()

  # 2. Create a empty result dicitonary
  results = {'train_loss': [],
            'val_loss' : [],
            'train_psnr': [],
            'val_psnr': []}

  # 3. Directory to save the model
  if not (os.path.exists("SRCNN/models")):
    os.makedirs("SRCNN/models")

  model_path = f"SRCNN/models/{path}.pth"

  early_stopper = EarlyStopping(patience=20, verbose=True, path=model_path)

  # Loop through training and testing steps for a number of epochs
  for epoch in tqdm(range(start_epoch, end_epoch)):

    train_loss, train_psnr = train_step(model=model,
                            dataloader=train_dataloader,
                            loss_fn=loss_fn,
                            optimizer=optimizer,
                            device=device)

    val_loss, val_psnr = test_step(model=model,
                          dataloader=test_dataloader,
                          loss_fn=loss_fn,
                          device=device)

    # Log PSNR values
    wandb.log({'epoch': epoch, 'train_loss': train_loss, 'val_loss': val_loss, 'train_psnr': train_psnr, 'val_psnr': val_psnr})

    # 4. Print out what's happening
    print(f"Epoch: {epoch+1} | train_loss: {train_loss:.4f} | val_loss: {val_loss:.4f} | train_psnr: {train_psnr:.2f} dB | val_psnr: {val_psnr:.2f} dB")

    # 5. Update results dictionary
    results["train_loss"].append(train_loss)
    results["val_loss"].append(val_loss)
    results["train_psnr"].append(train_psnr)
    results["val_psnr"].append(val_psnr)

    early_stopper(val_loss, model, optimizer)
    if early_stopper.early_stop:
        print("Early stopping")
        break

    # Checkpoint Saving
    if epoch % checkpoint_interval == 0 or epoch == end_epoch - 1:
        checkpoint_path = f"SRCNN/Checkpoints/{path}/epoch_{epoch}.pth"

        if not (os.path.exists(f"SRCNN/Checkpoints/{path}")):
          os.makedirs(f"SRCNN/Checkpoints/{path}")

        save_checkpoint(epoch=epoch, model=model, optimizer=optimizer, loss=val_loss, path=checkpoint_path)
        # Optionally log checkpoint to wandb
        wandb.save(checkpoint_path)

  # torch.save(model.state_dict(), model_path)

  # 6. Use wandb.save() to ensure the model file is saved to W&B
  wandb.save(model_path)

  # 7. Log the model as an artifact
  artifact = wandb.Artifact('SRCNNModel', type='model', description="A super-resolution model")
  artifact.add_file(model_path)
  wandb.log_artifact(artifact)

  # 9. Calculate and log training duration
  end_time = time.time()
  total_training_time = end_time - start_time
  wandb.log({'total_training_time': total_training_time})

  # 10. Print the training time
  print(f"Total training time: {total_training_time:.3f} seconds")

  # 11. Remember to finish the W&B run
  wandb.finish()

  # 12. Return the results dict
  return results

# %% [markdown]
# ## 5.8 Plot Loss Curves
#
# A loss curve is a way of tracking your model's progress over time

# %%
def plot_loss_curves(results):
    """Plot training and validation loss curves and PSNR curves."""
    # Extract values from the results dictionary
    train_loss = results['train_loss']
    val_loss = results['val_loss']
    train_psnr = results['train_psnr']
    val_psnr = results['val_psnr']

    # Calculate min and max values for loss and PSNR to dynamically set plot ranges
    min_loss = min(train_loss + val_loss)
    max_loss = max(train_loss + val_loss)
    min_psnr = min(train_psnr + val_psnr)
    max_psnr = max(train_psnr + val_psnr)

    # Setup the figure and axes
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

    # Plot Loss
    ax1.plot(train_loss, label='Training Loss', color='blue')
    ax1.plot(val_loss, label='Validation Loss', color='red')
    ax1.set_title('Loss Over Epochs')
    ax1.set_xlabel('Epoch')
    ax1.set_ylabel('Loss')
    ax1.set_ylim([min_loss - 0.05 * (max_loss - min_loss), max_loss + 0.05 * (max_loss - min_loss)])
    ax1.legend()

    # Plot PSNR
    ax2.plot(train_psnr, label='Training PSNR', color='blue')
    ax2.plot(val_psnr, label='Validation PSNR', color='red')
    ax2.set_title('PSNR Over Epochs')
    ax2.set_xlabel('Epoch')
    ax2.set_ylabel('PSNR (dB)')
    ax2.set_ylim([min_psnr - 0.05 * (max_psnr - min_psnr), max_psnr + 0.05 * (max_psnr - min_psnr)])
    ax2.legend()

    plt.tight_layout()
    plt.show()

# %% [markdown]
# # 6.0 Tracking experiments

# %%
# %%capture
# !pip install wandb

# %%
import os

# Set the API key
os.environ['WANDB_API_KEY'] = '0736c590933a18ad9639f49867ed1548495ded1c'

# %%
import wandb

# Log in to your W&B account
wandb.login()
# Out:
# wandb: Currently logged in as: pershadmayank. Use `wandb login --relogin` to force relogin
# True

# %% [markdown]
# ## 6.1 Config

# %%
# Initialize a W&B run
import wandb
wandb.init(project='SRCNN', entity='pershadmayank', config={
    'start_epoch': 0,
    'end_epoch': 1500,
    'learning_rate_first_two_layers': 1e-4,
    'learning_rate_last_layer': 1e-5,
    'architecture': 'SRCNN',
    'kernel_sizes': arch,
    'hidden_units_1': 64,
    'hidden_units_2': 32,
    'input_shape': 1,
    'output_shape': 1,
    'checkpoint_interval': 75  # Added to config for flexibility
})
# Out:
# Tracking run with wandb version 0.16.3
# Run data is saved locally in <code>/content/wandb/run-20240221_011216-gevc1x2t</code>
# Syncing run <strong><a href='https://wandb.ai/pershadmayank/SRCNN/runs/gevc1x2t' target="_blank">legendary-orchid-29</a></strong> to <a href='https://wandb.ai/pershadmayank/SRCNN' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/pershadmayank/SRCNN' target="_blank">https://wandb.ai/pershadmayank/SRCNN</a>
#  View run at <a href='https://wandb.ai/pershadmayank/SRCNN/runs/gevc1x2t' target="_blank">https://wandb.ai/pershadmayank/SRCNN/runs/gevc1x2t</a>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src='https://wandb.ai/pershadmayank/SRCNN/runs/gevc1x2t?jupyter=true' style='border:none;width:100%;height:420px;display:none;'></iframe>

# %% [markdown]
# ## 6.2 Setup Loss function and optimizer

# %%
import torch.nn as nn
import torch

# Set the random seed for reproducibility
# torch.manual_seed(42)
# torch.cuda.manual_seed(42)

# Access hyperparameters from wandb.config
config = wandb.config

# Recreate an instance of SRCNN Model using the wandb config
model_0 = SRCNNModel(input_shape=config.input_shape,
                     hidden_units_1=config.hidden_units_1,
                     hidden_units_2=config.hidden_units_2,
                     kernel_sizes=config.kernel_sizes,
                     output_shape=config.output_shape).to(device)

# Separate parameters for different learning rates
first_two_layers_params = list(model_0.conv_block_1.parameters())
last_layer_params = list(model_0.conv_block_2.parameters())

# Setup the optimizer with learning rates from wandb.config
optimizer = torch.optim.Adam([
    {'params': first_two_layers_params, 'lr': config.learning_rate_first_two_layers},
    {'params': last_layer_params, 'lr': config.learning_rate_last_layer}
])

# Setup the loss function
loss_fn = nn.MSELoss()

# %%
model_name = str(input("Enter model name:"))
# Out:
# Enter model name:model8_9_3_5

# %%
# Train the model using the wandb.config values
model_0_results = train(model=model_0,
                      train_dataloader=train_dataloader_custom,
                      test_dataloader=validation_dataloader_custom,
                      optimizer=optimizer,
                      loss_fn=loss_fn,
                      path=model_name,
                      start_epoch=config.start_epoch,
                      end_epoch=config.end_epoch,
                      device=device,
                      checkpoint_interval=config.checkpoint_interval)
# Out:
#   0%|          | 0/1500 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 0.0436 | val_loss: 0.0060 | train_psnr: 19.07 dB | val_psnr: 23.68 dB
# Validation loss decreased (inf --> 0.005962).  Saving model ...
# Checkpoint saved at 'SRCNN/Checkpoints/model8_9_3_5/epoch_0.pth'
# Epoch: 2 | train_loss: 0.0042 | val_loss: 0.0043 | train_psnr: 23.85 dB | val_psnr: 25.33 dB
# Validation loss decreased (0.005962 --> 0.004349).  Saving model ...
# Epoch: 3 | train_loss: 0.0037 | val_loss: 0.0042 | train_psnr: 24.39 dB | val_psnr: 25.46 dB
# Validation loss decreased (0.004349 --> 0.004230).  Saving model ...
# Epoch: 4 | train_loss: 0.0036 | val_loss: 0.0041 | train_psnr: 24.49 dB | val_psnr: 25.56 dB
# Validation loss decreased (0.004230 --> 0.004144).  Saving model ...
# Epoch: 5 | train_loss: 0.0035 | val_loss: 0.0041 | train_psnr: 24.57 dB | val_psnr: 25.66 dB
# Validation loss decreased (0.004144 --> 0.004067).  Saving model ...
# Epoch: 6 | train_loss: 0.0035 | val_loss: 0.0040 | train_psnr: 24.66 dB | val_psnr: 25.75 dB
# Validation loss decreased (0.004067 --> 0.003998).  Saving model ...
# Epoch: 7 | train_loss: 0.0034 | val_loss: 0.0039 | train_psnr: 24.72 dB | val_psnr: 25.84 dB
# Validation loss decreased (0.003998 --> 0.003932).  Saving model ...
# Epoch: 8 | train_loss: 0.0034 | val_loss: 0.0039 | train_psnr: 24.79 dB | val_psnr: 25.92 dB
# Validation loss decreased (0.003932 --> 0.003872).  Saving model ...
# Epoch: 9 | train_loss: 0.0033 | val_loss: 0.0038 | train_psnr: 24.87 dB | val_psnr: 25.97 dB
# Validation loss decreased (0.003872 --> 0.003834).  Saving model ...
# Epoch: 10 | train_loss: 0.0033 | val_loss: 0.0038 | train_psnr: 24.91 dB | val_psnr: 26.03 dB
# Validation loss decreased (0.003834 --> 0.003794).  Saving model ...
# Epoch: 11 | train_loss: 0.0033 | val_loss: 0.0038 | train_psnr: 24.94 dB | val_psnr: 26.07 dB
# Validation loss decreased (0.003794 --> 0.003768).  Saving model ...
# Epoch: 12 | train_loss: 0.0033 | val_loss: 0.0037 | train_psnr: 24.95 dB | val_psnr: 26.10 dB
# Validation loss decreased (0.003768 --> 0.003749).  Saving model ...
# Epoch: 13 | train_loss: 0.0032 | val_loss: 0.0037 | train_psnr: 24.97 dB | val_psnr: 26.11 dB
# Validation loss decreased (0.003749 --> 0.003737).  Saving model ...
# Epoch: 14 | train_loss: 0.0032 | val_loss: 0.0037 | train_psnr: 24.98 dB | val_psnr: 26.13 dB
# Validation loss decreased (0.003737 --> 0.003725).  Saving model ...
# Epoch: 15 | train_loss: 0.0032 | val_loss: 0.0037 | train_psnr: 25.00 dB | val_psnr: 26.07 dB
# EarlyStopping counter: 1 out of 20
# Epoch: 16 | train_loss: 0.0032 | val_loss: 0.0037 | train_psnr: 24.99 dB | val_psnr: 26.15 dB
# Validation loss decreased (0.003725 --> 0.003710).  Saving model ...
# Epoch: 17 | train_loss: 0.0032 | val_loss: 0.0037 | train_psnr: 24.99 dB | val_psnr: 26.15 dB
# Validation loss decreased (0.003710 --> 0.003706).  Saving model ...
# Epoch: 18 | train_loss: 0.0032 | val_loss: 0.0037 | train_psnr: 25.01 dB | val_psnr: 26.13 dB
# EarlyStopping counter: 1 out of 20
# Epoch: 19 | train_loss: 0.0032 | val_loss: 0.0037 | train_psnr: 25.01 dB | val_psnr: 26.16 dB
# Validation loss decreased (0.003706 --> 0.003695).  Saving model ...
# Epoch: 20 | train_loss: 0.0032 | val_loss: 0.0037 | train_psnr: 25.03 dB | val_psnr: 26.16 dB
# Validation loss decreased (0.003695 --> 0.003694).  Saving model ...
# Epoch: 21 | train_loss: 0.0032 | val_loss: 0.0037 | train_psnr: 25.02 dB | val_psnr: 26.16 dB
# Validation loss decreased (0.003694 --> 0.003692).  Saving model ...
# Epoch: 22 | train_loss: 0.0032 | val_loss: 0.0037 | train_psnr: 25.03 dB | val_psnr: 26.17 dB
# Validation loss decreased (0.003692 --> 0.003686).  Saving model ...
# Epoch: 23 | train_loss: 0.0032 | val_loss: 0.0037 | train_psnr: 25.04 dB | val_psnr: 26.19 dB
# Validation loss decreased (0.003686 --> 0.003678).  Saving model ...
# Epoch: 24 | train_loss: 0.0032 | val_loss: 0.0037 | train_psnr: 25.03 dB | val_psnr: 26.19 dB
# Validation loss decreased (0.003678 --> 0.003675).  Saving model ...
# Epoch: 25 | train_loss: 0.0032 | val_loss: 0.0037 | train_psnr: 25.03 dB | val_psnr: 26.18 dB
# Validation loss decreased (0.003675 --> 0.003674).  Saving model ...
# Epoch: 26 | train_loss: 0.0032 | val_loss: 0.0037 | train_psnr: 25.04 dB | val_psnr: 26.18 dB
# Validation loss decreased (0.003674 --> 0.003672).  Saving model ...
# Epoch: 27 | train_loss: 0.0032 | val_loss: 0.0037 | train_psnr: 25.04 dB | val_psnr: 26.20 dB
# Validation loss decreased (0.003672 --> 0.003665).  Saving model ...
# Epoch: 28 | train_loss: 0.0032 | val_loss: 0.0037 | train_psnr: 25.04 dB | val_psnr: 26.21 dB
# Validation loss decreased (0.003665 --> 0.003660).  Saving model ...
# Epoch: 29 | train_loss: 0.0032 | val_loss: 0.0037 | train_psnr: 25.06 dB | val_psnr: 26.21 dB
# Validation loss decreased (0.003660 --> 0.003656).  Saving model ...
# Epoch: 30 | train_loss: 0.0032 | val_loss: 0.0037 | train_psnr: 25.07 dB | val_psnr: 26.22 dB
# Validation loss decreased (0.003656 --> 0.003651).  Saving model ...
# Epoch: 31 | train_loss: 0.0032 | val_loss: 0.0037 | train_psnr: 25.07 dB | val_psnr: 26.21 dB
# EarlyStopping counter: 1 out of 20
# Epoch: 32 | train_loss: 0.0032 | val_loss: 0.0036 | train_psnr: 25.07 dB | val_psnr: 26.22 dB
# Validation loss decreased (0.003651 --> 0.003648).  Saving model ...
# Epoch: 33 | train_loss: 0.0032 | val_loss: 0.0036 | train_psnr: 25.06 dB | val_psnr: 26.21 dB
# Validation loss decreased (0.003648 --> 0.003647).  Saving model ...
# Epoch: 34 | train_loss: 0.0032 | val_loss: 0.0036 | train_psnr: 25.07 dB | val_psnr: 26.24 dB
# Validation loss decreased (0.003647 --> 0.003638).  Saving model ...
# Epoch: 35 | train_loss: 0.0032 | val_loss: 0.0037 | train_psnr: 25.07 dB | val_psnr: 26.19 dB
# EarlyStopping counter: 1 out of 20
# Epoch: 36 | train_loss: 0.0032 | val_loss: 0.0036 | train_psnr: 25.10 dB | val_psnr: 26.24 dB
# Validation loss decreased (0.003638 --> 0.003632).  Saving model ...
# Epoch: 37 | train_loss: 0.0032 | val_loss: 0.0036 | train_psnr: 25.08 dB | val_psnr: 26.22 dB
# EarlyStopping counter: 1 out of 20
# Epoch: 38 | train_loss: 0.0032 | val_loss: 0.0036 | train_psnr: 25.08 dB | val_psnr: 26.25 dB
# Validation loss decreased (0.003632 --> 0.003627).  Saving model ...
# Epoch: 39 | train_loss: 0.0032 | val_loss: 0.0036 | train_psnr: 25.09 dB | val_psnr: 26.25 dB
# Validation loss decreased (0.003627 --> 0.003622).  Saving model ...
# Epoch: 40 | train_loss: 0.0031 | val_loss: 0.0036 | train_psnr: 25.10 dB | val_psnr: 26.25 dB
# Validation loss decreased (0.003622 --> 0.003620).  Saving model ...
# Epoch: 41 | train_loss: 0.0031 | val_loss: 0.0036 | train_psnr: 25.09 dB | val_psnr: 26.27 dB
# Validation loss decreased (0.003620 --> 0.003613).  Saving model ...
# Epoch: 42 | train_loss: 0.0031 | val_loss: 0.0036 | train_psnr: 25.09 dB | val_psnr: 26.24 dB
# EarlyStopping counter: 1 out of 20
# Epoch: 43 | train_loss: 0.0031 | val_loss: 0.0036 | train_psnr: 25.10 dB | val_psnr: 26.28 dB
# Validation loss decreased (0.003613 --> 0.003603).  Saving model ...
# Epoch: 44 | train_loss: 0.0031 | val_loss: 0.0036 | train_psnr: 25.10 dB | val_psnr: 26.29 dB
# Validation loss decreased (0.003603 --> 0.003596).  Saving model ...
# Epoch: 45 | train_loss: 0.0031 | val_loss: 0.0036 | train_psnr: 25.12 dB | val_psnr: 26.26 dB
# EarlyStopping counter: 1 out of 20
# Epoch: 46 | train_loss: 0.0031 | val_loss: 0.0036 | train_psnr: 25.13 dB | val_psnr: 26.31 dB
# Validation loss decreased (0.003596 --> 0.003584).  Saving model ...
# Epoch: 47 | train_loss: 0.0031 | val_loss: 0.0036 | train_psnr: 25.14 dB | val_psnr: 26.31 dB
# Validation loss decreased (0.003584 --> 0.003577).  Saving model ...
# Epoch: 48 | train_loss: 0.0031 | val_loss: 0.0036 | train_psnr: 25.15 dB | val_psnr: 26.30 dB
# EarlyStopping counter: 1 out of 20
# Epoch: 49 | train_loss: 0.0031 | val_loss: 0.0036 | train_psnr: 25.15 dB | val_psnr: 26.31 dB
# Validation loss decreased (0.003577 --> 0.003570).  Saving model ...
# Epoch: 50 | train_loss: 0.0031 | val_loss: 0.0036 | train_psnr: 25.15 dB | val_psnr: 26.32 dB
# Validation loss decreased (0.003570 --> 0.003567).  Saving model ...
# Epoch: 51 | train_loss: 0.0031 | val_loss: 0.0036 | train_psnr: 25.15 dB | val_psnr: 26.33 dB
# Validation loss decreased (0.003567 --> 0.003560).  Saving model ...
# Epoch: 52 | train_loss: 0.0031 | val_loss: 0.0036 | train_psnr: 25.17 dB | val_psnr: 26.31 dB
# EarlyStopping counter: 1 out of 20
# Epoch: 53 | train_loss: 0.0031 | val_loss: 0.0036 | train_psnr: 25.16 dB | val_psnr: 26.28 dB
# EarlyStopping counter: 2 out of 20
# Epoch: 54 | train_loss: 0.0031 | val_loss: 0.0035 | train_psnr: 25.18 dB | val_psnr: 26.34 dB
# Validation loss decreased (0.003560 --> 0.003547).  Saving model ...
# Epoch: 55 | train_loss: 0.0031 | val_loss: 0.0035 | train_psnr: 25.16 dB | val_psnr: 26.34 dB
# Validation loss decreased (0.003547 --> 0.003545).  Saving model ...
# Epoch: 56 | train_loss: 0.0031 | val_loss: 0.0035 | train_psnr: 25.18 dB | val_psnr: 26.36 dB
# Validation loss decreased (0.003545 --> 0.003536).  Saving model ...
# Epoch: 57 | train_loss: 0.0031 | val_loss: 0.0035 | train_psnr: 25.18 dB | val_psnr: 26.37 dB
# Validation loss decreased (0.003536 --> 0.003532).  Saving model ...
# Epoch: 58 | train_loss: 0.0031 | val_loss: 0.0035 | train_psnr: 25.18 dB | val_psnr: 26.36 dB
# Validation loss decreased (0.003532 --> 0.003532).  Saving model ...
# Epoch: 59 | train_loss: 0.0031 | val_loss: 0.0035 | train_psnr: 25.18 dB | val_psnr: 26.38 dB
# Validation loss decreased (0.003532 --> 0.003525).  Saving model ...
# Epoch: 60 | train_loss: 0.0031 | val_loss: 0.0035 | train_psnr: 25.18 dB | val_psnr: 26.38 dB
# EarlyStopping counter: 1 out of 20
# Epoch: 61 | train_loss: 0.0031 | val_loss: 0.0035 | train_psnr: 25.19 dB | val_psnr: 26.37 dB
# Validation loss decreased (0.003525 --> 0.003524).  Saving model ...
# Epoch: 62 | train_loss: 0.0031 | val_loss: 0.0035 | train_psnr: 25.18 dB | val_psnr: 26.37 dB
# Validation loss decreased (0.003524 --> 0.003521).  Saving model ...
# Epoch: 63 | train_loss: 0.0031 | val_loss: 0.0035 | train_psnr: 25.19 dB | val_psnr: 26.36 dB
# EarlyStopping counter: 1 out of 20
# Epoch: 64 | train_loss: 0.0031 | val_loss: 0.0035 | train_psnr: 25.20 dB | val_psnr: 26.38 dB
# Validation loss decreased (0.003521 --> 0.003515).  Saving model ...
# Epoch: 65 | train_loss: 0.0031 | val_loss: 0.0035 | train_psnr: 25.21 dB | val_psnr: 26.39 dB
# Validation loss decreased (0.003515 --> 0.003509).  Saving model ...
# Epoch: 66 | train_loss: 0.0031 | val_loss: 0.0035 | train_psnr: 25.21 dB | val_psnr: 26.28 dB
# EarlyStopping counter: 1 out of 20
# Epoch: 67 | train_loss: 0.0031 | val_loss: 0.0035 | train_psnr: 25.20 dB | val_psnr: 26.40 dB
# Validation loss decreased (0.003509 --> 0.003501).  Saving model ...
# Epoch: 68 | train_loss: 0.0031 | val_loss: 0.0035 | train_psnr: 25.21 dB | val_psnr: 26.40 dB
# EarlyStopping counter: 1 out of 20
# Epoch: 69 | train_loss: 0.0031 | val_loss: 0.0035 | train_psnr: 25.21 dB | val_psnr: 26.39 dB
# EarlyStopping counter: 2 out of 20
# Epoch: 70 | train_loss: 0.0031 | val_loss: 0.0035 | train_psnr: 25.22 dB | val_psnr: 26.39 dB
# Validation loss decreased (0.003501 --> 0.003499).  Saving model ...
# Epoch: 71 | train_loss: 0.0031 | val_loss: 0.0035 | train_psnr: 25.23 dB | val_psnr: 26.41 dB
# Validation loss decreased (0.003499 --> 0.003493).  Saving model ...
# Epoch: 72 | train_loss: 0.0031 | val_loss: 0.0035 | train_psnr: 25.22 dB | val_psnr: 26.42 dB
# Validation loss decreased (0.003493 --> 0.003491).  Saving model ...
# Epoch: 73 | train_loss: 0.0031 | val_loss: 0.0035 | train_psnr: 25.22 dB | val_psnr: 26.35 dB
# EarlyStopping counter: 1 out of 20
# Epoch: 74 | train_loss: 0.0031 | val_loss: 0.0035 | train_psnr: 25.22 dB | val_psnr: 26.42 dB
# Validation loss decreased (0.003491 --> 0.003486).  Saving model ...
# Epoch: 75 | train_loss: 0.0031 | val_loss: 0.0035 | train_psnr: 25.24 dB | val_psnr: 26.37 dB
# EarlyStopping counter: 1 out of 20
# Epoch: 76 | train_loss: 0.0031 | val_loss: 0.0035 | train_psnr: 25.23 dB | val_psnr: 26.42 dB
# Validation loss decreased (0.003486 --> 0.003486).  Saving model ...
# Checkpoint saved at 'SRCNN/Checkpoints/model8_9_3_5/epoch_75.pth'
# Epoch: 77 | train_loss: 0.0031 | val_loss: 0.0035 | train_psnr: 25.22 dB | val_psnr: 26.42 dB
# Validation loss decreased (0.003486 --> 0.003484).  Saving model ...
# Epoch: 78 | train_loss: 0.0031 | val_loss: 0.0035 | train_psnr: 25.22 dB | val_psnr: 26.43 dB
# Validation loss decreased (0.003484 --> 0.003480).  Saving model ...
# Epoch: 79 | train_loss: 0.0031 | val_loss: 0.0035 | train_psnr: 25.24 dB | val_psnr: 26.44 dB
# Validation loss decreased (0.003480 --> 0.003476).  Saving model ...
# Epoch: 80 | train_loss: 0.0031 | val_loss: 0.0035 | train_psnr: 25.23 dB | val_psnr: 26.44 dB
# Validation loss decreased (0.003476 --> 0.003474).  Saving model ...
# Epoch: 81 | train_loss: 0.0030 | val_loss: 0.0035 | train_psnr: 25.23 dB | val_psnr: 26.44 dB
# Validation loss decreased (0.003474 --> 0.003473).  Saving model ...
# Epoch: 82 | train_loss: 0.0030 | val_loss: 0.0035 | train_psnr: 25.25 dB | val_psnr: 26.45 dB
# Validation loss decreased (0.003473 --> 0.003470).  Saving model ...
# Epoch: 83 | train_loss: 0.0030 | val_loss: 0.0035 | train_psnr: 25.24 dB | val_psnr: 26.44 dB
# EarlyStopping counter: 1 out of 20
# Epoch: 84 | train_loss: 0.0030 | val_loss: 0.0035 | train_psnr: 25.23 dB | val_psnr: 26.44 dB
# EarlyStopping counter: 2 out of 20
# Epoch: 85 | train_loss: 0.0030 | val_loss: 0.0035 | train_psnr: 25.24 dB | val_psnr: 26.37 dB
# EarlyStopping counter: 3 out of 20
# Epoch: 86 | train_loss: 0.0030 | val_loss: 0.0035 | train_psnr: 25.24 dB | val_psnr: 26.45 dB
# Validation loss decreased (0.003470 --> 0.003466).  Saving model ...
# Epoch: 87 | train_loss: 0.0030 | val_loss: 0.0035 | train_psnr: 25.24 dB | val_psnr: 26.46 dB
# Validation loss decreased (0.003466 --> 0.003465).  Saving model ...
# Epoch: 88 | train_loss: 0.0030 | val_loss: 0.0035 | train_psnr: 25.24 dB | val_psnr: 26.46 dB
# Validation loss decreased (0.003465 --> 0.003464).  Saving model ...
# Epoch: 89 | train_loss: 0.0030 | val_loss: 0.0035 | train_psnr: 25.25 dB | val_psnr: 26.46 dB
# Validation loss decreased (0.003464 --> 0.003461).  Saving model ...
# Epoch: 90 | train_loss: 0.0030 | val_loss: 0.0035 | train_psnr: 25.25 dB | val_psnr: 26.46 dB
# Validation loss decreased (0.003461 --> 0.003460).  Saving model ...
# Epoch: 91 | train_loss: 0.0030 | val_loss: 0.0035 | train_psnr: 25.26 dB | val_psnr: 26.46 dB
# EarlyStopping counter: 1 out of 20
# Epoch: 92 | train_loss: 0.0030 | val_loss: 0.0035 | train_psnr: 25.26 dB | val_psnr: 26.46 dB
# Validation loss decreased (0.003460 --> 0.003455).  Saving model ...
# Epoch: 93 | train_loss: 0.0030 | val_loss: 0.0035 | train_psnr: 25.25 dB | val_psnr: 26.42 dB
# EarlyStopping counter: 1 out of 20
# Epoch: 94 | train_loss: 0.0030 | val_loss: 0.0035 | train_psnr: 25.27 dB | val_psnr: 26.46 dB
# EarlyStopping counter: 2 out of 20
# Epoch: 95 | train_loss: 0.0030 | val_loss: 0.0035 | train_psnr: 25.28 dB | val_psnr: 26.47 dB
# Validation loss decreased (0.003455 --> 0.003453).  Saving model ...
# Epoch: 96 | train_loss: 0.0030 | val_loss: 0.0035 | train_psnr: 25.27 dB | val_psnr: 26.47 dB
# EarlyStopping counter: 1 out of 20
# Epoch: 97 | train_loss: 0.0030 | val_loss: 0.0035 | train_psnr: 25.27 dB | val_psnr: 26.47 dB
# EarlyStopping counter: 2 out of 20
# Epoch: 98 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.27 dB | val_psnr: 26.48 dB
# Validation loss decreased (0.003453 --> 0.003446).  Saving model ...
# Epoch: 99 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.27 dB | val_psnr: 26.48 dB
# EarlyStopping counter: 1 out of 20
# Epoch: 100 | train_loss: 0.0030 | val_loss: 0.0035 | train_psnr: 25.27 dB | val_psnr: 26.44 dB
# EarlyStopping counter: 2 out of 20
# Epoch: 101 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.26 dB | val_psnr: 26.48 dB
# Validation loss decreased (0.003446 --> 0.003445).  Saving model ...
# Epoch: 102 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.28 dB | val_psnr: 26.48 dB
# EarlyStopping counter: 1 out of 20
# Epoch: 103 | train_loss: 0.0030 | val_loss: 0.0035 | train_psnr: 25.27 dB | val_psnr: 26.43 dB
# EarlyStopping counter: 2 out of 20
# Epoch: 104 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.27 dB | val_psnr: 26.49 dB
# Validation loss decreased (0.003445 --> 0.003443).  Saving model ...
# Epoch: 105 | train_loss: 0.0030 | val_loss: 0.0035 | train_psnr: 25.28 dB | val_psnr: 26.37 dB
# EarlyStopping counter: 1 out of 20
# Epoch: 106 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.29 dB | val_psnr: 26.49 dB
# EarlyStopping counter: 2 out of 20
# Epoch: 107 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.28 dB | val_psnr: 26.48 dB
# EarlyStopping counter: 3 out of 20
# Epoch: 108 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.30 dB | val_psnr: 26.49 dB
# EarlyStopping counter: 4 out of 20
# Epoch: 109 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.28 dB | val_psnr: 26.49 dB
# Validation loss decreased (0.003443 --> 0.003439).  Saving model ...
# Epoch: 110 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.28 dB | val_psnr: 26.50 dB
# EarlyStopping counter: 1 out of 20
# Epoch: 111 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.29 dB | val_psnr: 26.50 dB
# Validation loss decreased (0.003439 --> 0.003438).  Saving model ...
# Epoch: 112 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.30 dB | val_psnr: 26.50 dB
# Validation loss decreased (0.003438 --> 0.003436).  Saving model ...
# Epoch: 113 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.29 dB | val_psnr: 26.50 dB
# EarlyStopping counter: 1 out of 20
# Epoch: 114 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.28 dB | val_psnr: 26.48 dB
# EarlyStopping counter: 2 out of 20
# Epoch: 115 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.30 dB | val_psnr: 26.50 dB
# Validation loss decreased (0.003436 --> 0.003430).  Saving model ...
# Epoch: 116 | train_loss: 0.0030 | val_loss: 0.0035 | train_psnr: 25.29 dB | val_psnr: 26.31 dB
# EarlyStopping counter: 1 out of 20
# Epoch: 117 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.30 dB | val_psnr: 26.50 dB
# EarlyStopping counter: 2 out of 20
# Epoch: 118 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.29 dB | val_psnr: 26.50 dB
# EarlyStopping counter: 3 out of 20
# Epoch: 119 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.31 dB | val_psnr: 26.51 dB
# Validation loss decreased (0.003430 --> 0.003426).  Saving model ...
# Epoch: 120 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.29 dB | val_psnr: 26.51 dB
# Validation loss decreased (0.003426 --> 0.003426).  Saving model ...
# Epoch: 121 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.30 dB | val_psnr: 26.51 dB
# Validation loss decreased (0.003426 --> 0.003425).  Saving model ...
# Epoch: 122 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.30 dB | val_psnr: 26.51 dB
# Validation loss decreased (0.003425 --> 0.003424).  Saving model ...
# Epoch: 123 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.30 dB | val_psnr: 26.49 dB
# EarlyStopping counter: 1 out of 20
# Epoch: 124 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.31 dB | val_psnr: 26.50 dB
# EarlyStopping counter: 2 out of 20
# Epoch: 125 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.30 dB | val_psnr: 26.50 dB
# EarlyStopping counter: 3 out of 20
# Epoch: 126 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.30 dB | val_psnr: 26.47 dB
# EarlyStopping counter: 4 out of 20
# Epoch: 127 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.30 dB | val_psnr: 26.50 dB
# EarlyStopping counter: 5 out of 20
# Epoch: 128 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.30 dB | val_psnr: 26.50 dB
# EarlyStopping counter: 6 out of 20
# Epoch: 129 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.31 dB | val_psnr: 26.52 dB
# Validation loss decreased (0.003424 --> 0.003421).  Saving model ...
# Epoch: 130 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.31 dB | val_psnr: 26.52 dB
# Validation loss decreased (0.003421 --> 0.003418).  Saving model ...
# Epoch: 131 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.31 dB | val_psnr: 26.51 dB
# EarlyStopping counter: 1 out of 20
# Epoch: 132 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.30 dB | val_psnr: 26.48 dB
# EarlyStopping counter: 2 out of 20
# Epoch: 133 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.29 dB | val_psnr: 26.51 dB
# EarlyStopping counter: 3 out of 20
# Epoch: 134 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.30 dB | val_psnr: 26.51 dB
# EarlyStopping counter: 4 out of 20
# Epoch: 135 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.30 dB | val_psnr: 26.48 dB
# EarlyStopping counter: 5 out of 20
# Epoch: 136 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.31 dB | val_psnr: 26.51 dB
# EarlyStopping counter: 6 out of 20
# Epoch: 137 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.31 dB | val_psnr: 26.51 dB
# EarlyStopping counter: 7 out of 20
# Epoch: 138 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.32 dB | val_psnr: 26.51 dB
# Validation loss decreased (0.003418 --> 0.003416).  Saving model ...
# Epoch: 139 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.31 dB | val_psnr: 26.52 dB
# EarlyStopping counter: 1 out of 20
# Epoch: 140 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.31 dB | val_psnr: 26.53 dB
# Validation loss decreased (0.003416 --> 0.003416).  Saving model ...
# Epoch: 141 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.31 dB | val_psnr: 26.52 dB
# EarlyStopping counter: 1 out of 20
# Epoch: 142 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.31 dB | val_psnr: 26.50 dB
# EarlyStopping counter: 2 out of 20
# Epoch: 143 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.31 dB | val_psnr: 26.52 dB
# EarlyStopping counter: 3 out of 20
# Epoch: 144 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.32 dB | val_psnr: 26.51 dB
# EarlyStopping counter: 4 out of 20
# Epoch: 145 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.32 dB | val_psnr: 26.53 dB
# EarlyStopping counter: 5 out of 20
# Epoch: 146 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.31 dB | val_psnr: 26.52 dB
# EarlyStopping counter: 6 out of 20
# Epoch: 147 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.33 dB | val_psnr: 26.53 dB
# Validation loss decreased (0.003416 --> 0.003413).  Saving model ...
# Epoch: 148 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.32 dB | val_psnr: 26.53 dB
# EarlyStopping counter: 1 out of 20
# Epoch: 149 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.33 dB | val_psnr: 26.49 dB
# EarlyStopping counter: 2 out of 20
# Epoch: 150 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.31 dB | val_psnr: 26.52 dB
# EarlyStopping counter: 3 out of 20
# Epoch: 151 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.32 dB | val_psnr: 26.46 dB
# EarlyStopping counter: 4 out of 20
# Checkpoint saved at 'SRCNN/Checkpoints/model8_9_3_5/epoch_150.pth'
# Epoch: 152 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.32 dB | val_psnr: 26.53 dB
# Validation loss decreased (0.003413 --> 0.003411).  Saving model ...
# Epoch: 153 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.32 dB | val_psnr: 26.51 dB
# EarlyStopping counter: 1 out of 20
# Epoch: 154 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.33 dB | val_psnr: 26.53 dB
# EarlyStopping counter: 2 out of 20
# Epoch: 155 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.32 dB | val_psnr: 26.53 dB
# Validation loss decreased (0.003411 --> 0.003411).  Saving model ...
# Epoch: 156 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.32 dB | val_psnr: 26.53 dB
# Validation loss decreased (0.003411 --> 0.003410).  Saving model ...
# Epoch: 157 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.32 dB | val_psnr: 26.53 dB
# Validation loss decreased (0.003410 --> 0.003410).  Saving model ...
# Epoch: 158 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.32 dB | val_psnr: 26.47 dB
# EarlyStopping counter: 1 out of 20
# Epoch: 159 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.32 dB | val_psnr: 26.53 dB
# EarlyStopping counter: 2 out of 20
# Epoch: 160 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.32 dB | val_psnr: 26.53 dB
# EarlyStopping counter: 3 out of 20
# Epoch: 161 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.33 dB | val_psnr: 26.53 dB
# EarlyStopping counter: 4 out of 20
# Epoch: 162 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.32 dB | val_psnr: 26.53 dB
# EarlyStopping counter: 5 out of 20
# Epoch: 163 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.31 dB | val_psnr: 26.51 dB
# EarlyStopping counter: 6 out of 20
# Epoch: 164 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.32 dB | val_psnr: 26.51 dB
# EarlyStopping counter: 7 out of 20
# Epoch: 165 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.32 dB | val_psnr: 26.54 dB
# Validation loss decreased (0.003410 --> 0.003408).  Saving model ...
# Epoch: 166 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.32 dB | val_psnr: 26.53 dB
# EarlyStopping counter: 1 out of 20
# Epoch: 167 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.32 dB | val_psnr: 26.52 dB
# EarlyStopping counter: 2 out of 20
# Epoch: 168 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.32 dB | val_psnr: 26.54 dB
# EarlyStopping counter: 3 out of 20
# Epoch: 169 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.32 dB | val_psnr: 26.53 dB
# EarlyStopping counter: 4 out of 20
# Epoch: 170 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.32 dB | val_psnr: 26.54 dB
# EarlyStopping counter: 5 out of 20
# Epoch: 171 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.32 dB | val_psnr: 26.54 dB
# EarlyStopping counter: 6 out of 20
# Epoch: 172 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.33 dB | val_psnr: 26.53 dB
# EarlyStopping counter: 7 out of 20
# Epoch: 173 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.32 dB | val_psnr: 26.53 dB
# EarlyStopping counter: 8 out of 20
# Epoch: 174 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.32 dB | val_psnr: 26.51 dB
# EarlyStopping counter: 9 out of 20
# Epoch: 175 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.32 dB | val_psnr: 26.53 dB
# Validation loss decreased (0.003408 --> 0.003406).  Saving model ...
# Epoch: 176 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.33 dB | val_psnr: 26.53 dB
# EarlyStopping counter: 1 out of 20
# Epoch: 177 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.32 dB | val_psnr: 26.53 dB
# EarlyStopping counter: 2 out of 20
# Epoch: 178 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.32 dB | val_psnr: 26.45 dB
# EarlyStopping counter: 3 out of 20
# Epoch: 179 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.32 dB | val_psnr: 26.50 dB
# EarlyStopping counter: 4 out of 20
# Epoch: 180 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.32 dB | val_psnr: 26.54 dB
# Validation loss decreased (0.003406 --> 0.003406).  Saving model ...
# Epoch: 181 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.32 dB | val_psnr: 26.52 dB
# EarlyStopping counter: 1 out of 20
# Epoch: 182 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.33 dB | val_psnr: 26.46 dB
# EarlyStopping counter: 2 out of 20
# Epoch: 183 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.34 dB | val_psnr: 26.54 dB
# EarlyStopping counter: 3 out of 20
# Epoch: 184 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.34 dB | val_psnr: 26.54 dB
# EarlyStopping counter: 4 out of 20
# Epoch: 185 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.33 dB | val_psnr: 26.54 dB
# Validation loss decreased (0.003406 --> 0.003405).  Saving model ...
# Epoch: 186 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.33 dB | val_psnr: 26.54 dB
# EarlyStopping counter: 1 out of 20
# Epoch: 187 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.32 dB | val_psnr: 26.52 dB
# EarlyStopping counter: 2 out of 20
# Epoch: 188 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.32 dB | val_psnr: 26.54 dB
# EarlyStopping counter: 3 out of 20
# Epoch: 189 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.33 dB | val_psnr: 26.54 dB
# EarlyStopping counter: 4 out of 20
# Epoch: 190 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.33 dB | val_psnr: 26.55 dB
# EarlyStopping counter: 5 out of 20
# Epoch: 191 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.33 dB | val_psnr: 26.54 dB
# EarlyStopping counter: 6 out of 20
# Epoch: 192 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.32 dB | val_psnr: 26.54 dB
# EarlyStopping counter: 7 out of 20
# Epoch: 193 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.33 dB | val_psnr: 26.53 dB
# EarlyStopping counter: 8 out of 20
# Epoch: 194 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.32 dB | val_psnr: 26.54 dB
# EarlyStopping counter: 9 out of 20
# Epoch: 195 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.34 dB | val_psnr: 26.52 dB
# EarlyStopping counter: 10 out of 20
# Epoch: 196 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.33 dB | val_psnr: 26.54 dB
# EarlyStopping counter: 11 out of 20
# Epoch: 197 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.33 dB | val_psnr: 26.54 dB
# Validation loss decreased (0.003405 --> 0.003405).  Saving model ...
# Epoch: 198 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.33 dB | val_psnr: 26.54 dB
# EarlyStopping counter: 1 out of 20
# Epoch: 199 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.34 dB | val_psnr: 26.46 dB
# EarlyStopping counter: 2 out of 20
# Epoch: 200 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.34 dB | val_psnr: 26.51 dB
# EarlyStopping counter: 3 out of 20
# Epoch: 201 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.33 dB | val_psnr: 26.51 dB
# EarlyStopping counter: 4 out of 20
# Epoch: 202 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.34 dB | val_psnr: 26.48 dB
# EarlyStopping counter: 5 out of 20
# Epoch: 203 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.34 dB | val_psnr: 26.55 dB
# EarlyStopping counter: 6 out of 20
# Epoch: 204 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.32 dB | val_psnr: 26.45 dB
# EarlyStopping counter: 7 out of 20
# Epoch: 205 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.32 dB | val_psnr: 26.53 dB
# EarlyStopping counter: 8 out of 20
# Epoch: 206 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.32 dB | val_psnr: 26.52 dB
# EarlyStopping counter: 9 out of 20
# Epoch: 207 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.33 dB | val_psnr: 26.53 dB
# EarlyStopping counter: 10 out of 20
# Epoch: 208 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.34 dB | val_psnr: 26.50 dB
# EarlyStopping counter: 11 out of 20
# Epoch: 209 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.34 dB | val_psnr: 26.55 dB
# Validation loss decreased (0.003405 --> 0.003404).  Saving model ...
# Epoch: 210 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.34 dB | val_psnr: 26.53 dB
# EarlyStopping counter: 1 out of 20
# Epoch: 211 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.34 dB | val_psnr: 26.54 dB
# EarlyStopping counter: 2 out of 20
# Epoch: 212 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.34 dB | val_psnr: 26.54 dB
# Validation loss decreased (0.003404 --> 0.003402).  Saving model ...
# Epoch: 213 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.34 dB | val_psnr: 26.55 dB
# Validation loss decreased (0.003402 --> 0.003402).  Saving model ...
# Epoch: 214 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.33 dB | val_psnr: 26.55 dB
# EarlyStopping counter: 1 out of 20
# Epoch: 215 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.34 dB | val_psnr: 26.49 dB
# EarlyStopping counter: 2 out of 20
# Epoch: 216 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.34 dB | val_psnr: 26.56 dB
# Validation loss decreased (0.003402 --> 0.003399).  Saving model ...
# Epoch: 217 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.34 dB | val_psnr: 26.56 dB
# Validation loss decreased (0.003399 --> 0.003399).  Saving model ...
# Epoch: 218 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.33 dB | val_psnr: 26.51 dB
# EarlyStopping counter: 1 out of 20
# Epoch: 219 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.34 dB | val_psnr: 26.55 dB
# EarlyStopping counter: 2 out of 20
# Epoch: 220 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.34 dB | val_psnr: 26.55 dB
# EarlyStopping counter: 3 out of 20
# Epoch: 221 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.34 dB | val_psnr: 26.55 dB
# EarlyStopping counter: 4 out of 20
# Epoch: 222 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.34 dB | val_psnr: 26.55 dB
# Validation loss decreased (0.003399 --> 0.003398).  Saving model ...
# Epoch: 223 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.35 dB | val_psnr: 26.56 dB
# Validation loss decreased (0.003398 --> 0.003397).  Saving model ...
# Epoch: 224 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.33 dB | val_psnr: 26.55 dB
# Validation loss decreased (0.003397 --> 0.003396).  Saving model ...
# Epoch: 225 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.34 dB | val_psnr: 26.54 dB
# EarlyStopping counter: 1 out of 20
# Epoch: 226 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.35 dB | val_psnr: 26.56 dB
# Validation loss decreased (0.003396 --> 0.003394).  Saving model ...
# Checkpoint saved at 'SRCNN/Checkpoints/model8_9_3_5/epoch_225.pth'
# Epoch: 227 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.35 dB | val_psnr: 26.55 dB
# EarlyStopping counter: 1 out of 20
# Epoch: 228 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.33 dB | val_psnr: 26.56 dB
# EarlyStopping counter: 2 out of 20
# Epoch: 229 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.33 dB | val_psnr: 26.56 dB
# Validation loss decreased (0.003394 --> 0.003393).  Saving model ...
# Epoch: 230 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.33 dB | val_psnr: 26.55 dB
# EarlyStopping counter: 1 out of 20
# Epoch: 231 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.34 dB | val_psnr: 26.53 dB
# EarlyStopping counter: 2 out of 20
# Epoch: 232 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.34 dB | val_psnr: 26.57 dB
# EarlyStopping counter: 3 out of 20
# Epoch: 233 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.34 dB | val_psnr: 26.56 dB
# EarlyStopping counter: 4 out of 20
# Epoch: 234 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.33 dB | val_psnr: 26.56 dB
# Validation loss decreased (0.003393 --> 0.003393).  Saving model ...
# Epoch: 235 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.34 dB | val_psnr: 26.56 dB
# Validation loss decreased (0.003393 --> 0.003392).  Saving model ...
# Epoch: 236 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.34 dB | val_psnr: 26.53 dB
# EarlyStopping counter: 1 out of 20
# Epoch: 237 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.34 dB | val_psnr: 26.52 dB
# EarlyStopping counter: 2 out of 20
# Epoch: 238 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.33 dB | val_psnr: 26.56 dB
# EarlyStopping counter: 3 out of 20
# Epoch: 239 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.33 dB | val_psnr: 26.57 dB
# Validation loss decreased (0.003392 --> 0.003392).  Saving model ...
# Epoch: 240 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.34 dB | val_psnr: 26.55 dB
# EarlyStopping counter: 1 out of 20
# Epoch: 241 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.35 dB | val_psnr: 26.56 dB
# EarlyStopping counter: 2 out of 20
# Epoch: 242 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.35 dB | val_psnr: 26.56 dB
# Validation loss decreased (0.003392 --> 0.003391).  Saving model ...
# Epoch: 243 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.35 dB | val_psnr: 26.57 dB
# EarlyStopping counter: 1 out of 20
# Epoch: 244 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.35 dB | val_psnr: 26.56 dB
# Validation loss decreased (0.003391 --> 0.003391).  Saving model ...
# Epoch: 245 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.36 dB | val_psnr: 26.56 dB
# EarlyStopping counter: 1 out of 20
# Epoch: 246 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.35 dB | val_psnr: 26.53 dB
# EarlyStopping counter: 2 out of 20
# Epoch: 247 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.34 dB | val_psnr: 26.55 dB
# EarlyStopping counter: 3 out of 20
# Epoch: 248 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.35 dB | val_psnr: 26.42 dB
# EarlyStopping counter: 4 out of 20
# Epoch: 249 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.35 dB | val_psnr: 26.57 dB
# EarlyStopping counter: 5 out of 20
# Epoch: 250 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.35 dB | val_psnr: 26.57 dB
# Validation loss decreased (0.003391 --> 0.003390).  Saving model ...
# Epoch: 251 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.36 dB | val_psnr: 26.56 dB
# EarlyStopping counter: 1 out of 20
# Epoch: 252 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.34 dB | val_psnr: 26.57 dB
# Validation loss decreased (0.003390 --> 0.003389).  Saving model ...
# Epoch: 253 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.35 dB | val_psnr: 26.57 dB
# Validation loss decreased (0.003389 --> 0.003388).  Saving model ...
# Epoch: 254 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.35 dB | val_psnr: 26.56 dB
# EarlyStopping counter: 1 out of 20
# Epoch: 255 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.35 dB | val_psnr: 26.57 dB
# EarlyStopping counter: 2 out of 20
# Epoch: 256 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.34 dB | val_psnr: 26.56 dB
# Validation loss decreased (0.003388 --> 0.003388).  Saving model ...
# Epoch: 257 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.35 dB | val_psnr: 26.57 dB
# EarlyStopping counter: 1 out of 20
# Epoch: 258 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.35 dB | val_psnr: 26.53 dB
# EarlyStopping counter: 2 out of 20
# Epoch: 259 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.35 dB | val_psnr: 26.52 dB
# EarlyStopping counter: 3 out of 20
# Epoch: 260 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.35 dB | val_psnr: 26.57 dB
# EarlyStopping counter: 4 out of 20
# Epoch: 261 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.36 dB | val_psnr: 26.56 dB
# EarlyStopping counter: 5 out of 20
# Epoch: 262 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.35 dB | val_psnr: 26.56 dB
# EarlyStopping counter: 6 out of 20
# Epoch: 263 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.35 dB | val_psnr: 26.55 dB
# EarlyStopping counter: 7 out of 20
# Epoch: 264 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.35 dB | val_psnr: 26.57 dB
# EarlyStopping counter: 8 out of 20
# Epoch: 265 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.35 dB | val_psnr: 26.54 dB
# EarlyStopping counter: 9 out of 20
# Epoch: 266 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.35 dB | val_psnr: 26.53 dB
# EarlyStopping counter: 10 out of 20
# Epoch: 267 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.35 dB | val_psnr: 26.53 dB
# EarlyStopping counter: 11 out of 20
# Epoch: 268 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.36 dB | val_psnr: 26.56 dB
# EarlyStopping counter: 12 out of 20
# Epoch: 269 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.36 dB | val_psnr: 26.57 dB
# EarlyStopping counter: 13 out of 20
# Epoch: 270 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.36 dB | val_psnr: 26.50 dB
# EarlyStopping counter: 14 out of 20
# Epoch: 271 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.35 dB | val_psnr: 26.57 dB
# Validation loss decreased (0.003388 --> 0.003387).  Saving model ...
# Epoch: 272 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.35 dB | val_psnr: 26.57 dB
# EarlyStopping counter: 1 out of 20
# Epoch: 273 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.35 dB | val_psnr: 26.56 dB
# EarlyStopping counter: 2 out of 20
# Epoch: 274 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.35 dB | val_psnr: 26.57 dB
# EarlyStopping counter: 3 out of 20
# Epoch: 275 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.36 dB | val_psnr: 26.56 dB
# EarlyStopping counter: 4 out of 20
# Epoch: 276 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.35 dB | val_psnr: 26.57 dB
# Validation loss decreased (0.003387 --> 0.003386).  Saving model ...
# Epoch: 277 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.36 dB | val_psnr: 26.55 dB
# EarlyStopping counter: 1 out of 20
# Epoch: 278 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.36 dB | val_psnr: 26.56 dB
# EarlyStopping counter: 2 out of 20
# Epoch: 279 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.36 dB | val_psnr: 26.57 dB
# EarlyStopping counter: 3 out of 20
# Epoch: 280 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.35 dB | val_psnr: 26.58 dB
# EarlyStopping counter: 4 out of 20
# Epoch: 281 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.35 dB | val_psnr: 26.53 dB
# EarlyStopping counter: 5 out of 20
# Epoch: 282 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.35 dB | val_psnr: 26.58 dB
# EarlyStopping counter: 6 out of 20
# Epoch: 283 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.36 dB | val_psnr: 26.57 dB
# EarlyStopping counter: 7 out of 20
# Epoch: 284 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.35 dB | val_psnr: 26.48 dB
# EarlyStopping counter: 8 out of 20
# Epoch: 285 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.36 dB | val_psnr: 26.57 dB
# EarlyStopping counter: 9 out of 20
# Epoch: 286 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.36 dB | val_psnr: 26.56 dB
# EarlyStopping counter: 10 out of 20
# Epoch: 287 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.35 dB | val_psnr: 26.57 dB
# EarlyStopping counter: 11 out of 20
# Epoch: 288 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.35 dB | val_psnr: 26.55 dB
# EarlyStopping counter: 12 out of 20
# Epoch: 289 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.35 dB | val_psnr: 26.58 dB
# Validation loss decreased (0.003386 --> 0.003384).  Saving model ...
# Epoch: 290 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.37 dB | val_psnr: 26.51 dB
# EarlyStopping counter: 1 out of 20
# Epoch: 291 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.37 dB | val_psnr: 26.58 dB
# EarlyStopping counter: 2 out of 20
# Epoch: 292 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.37 dB | val_psnr: 26.56 dB
# EarlyStopping counter: 3 out of 20
# Epoch: 293 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.35 dB | val_psnr: 26.57 dB
# EarlyStopping counter: 4 out of 20
# Epoch: 294 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.37 dB | val_psnr: 26.57 dB
# EarlyStopping counter: 5 out of 20
# Epoch: 295 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.36 dB | val_psnr: 26.39 dB
# EarlyStopping counter: 6 out of 20
# Epoch: 296 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.36 dB | val_psnr: 26.57 dB
# EarlyStopping counter: 7 out of 20
# Epoch: 297 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.36 dB | val_psnr: 26.57 dB
# EarlyStopping counter: 8 out of 20
# Epoch: 298 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.36 dB | val_psnr: 26.55 dB
# EarlyStopping counter: 9 out of 20
# Epoch: 299 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.36 dB | val_psnr: 26.57 dB
# EarlyStopping counter: 10 out of 20
# Epoch: 300 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.36 dB | val_psnr: 26.57 dB
# EarlyStopping counter: 11 out of 20
# Epoch: 301 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.36 dB | val_psnr: 26.55 dB
# EarlyStopping counter: 12 out of 20
# Checkpoint saved at 'SRCNN/Checkpoints/model8_9_3_5/epoch_300.pth'
# Epoch: 302 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.36 dB | val_psnr: 26.57 dB
# EarlyStopping counter: 13 out of 20
# Epoch: 303 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.36 dB | val_psnr: 26.57 dB
# Validation loss decreased (0.003384 --> 0.003383).  Saving model ...
# Epoch: 304 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.36 dB | val_psnr: 26.56 dB
# EarlyStopping counter: 1 out of 20
# Epoch: 305 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.37 dB | val_psnr: 26.58 dB
# EarlyStopping counter: 2 out of 20
# Epoch: 306 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.36 dB | val_psnr: 26.48 dB
# EarlyStopping counter: 3 out of 20
# Epoch: 307 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.36 dB | val_psnr: 26.57 dB
# EarlyStopping counter: 4 out of 20
# Epoch: 308 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.36 dB | val_psnr: 26.56 dB
# EarlyStopping counter: 5 out of 20
# Epoch: 309 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.37 dB | val_psnr: 26.58 dB
# EarlyStopping counter: 6 out of 20
# Epoch: 310 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.37 dB | val_psnr: 26.58 dB
# EarlyStopping counter: 7 out of 20
# Epoch: 311 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.36 dB | val_psnr: 26.57 dB
# EarlyStopping counter: 8 out of 20
# Epoch: 312 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.36 dB | val_psnr: 26.55 dB
# EarlyStopping counter: 9 out of 20
# Epoch: 313 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.36 dB | val_psnr: 26.55 dB
# EarlyStopping counter: 10 out of 20
# Epoch: 314 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.37 dB | val_psnr: 26.58 dB
# EarlyStopping counter: 11 out of 20
# Epoch: 315 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.37 dB | val_psnr: 26.58 dB
# EarlyStopping counter: 12 out of 20
# Epoch: 316 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.37 dB | val_psnr: 26.54 dB
# EarlyStopping counter: 13 out of 20
# Epoch: 317 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.37 dB | val_psnr: 26.57 dB
# EarlyStopping counter: 14 out of 20
# Epoch: 318 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.36 dB | val_psnr: 26.58 dB
# EarlyStopping counter: 15 out of 20
# Epoch: 319 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.37 dB | val_psnr: 26.55 dB
# EarlyStopping counter: 16 out of 20
# Epoch: 320 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.36 dB | val_psnr: 26.50 dB
# EarlyStopping counter: 17 out of 20
# Epoch: 321 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.36 dB | val_psnr: 26.49 dB
# EarlyStopping counter: 18 out of 20
# Epoch: 322 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.37 dB | val_psnr: 26.58 dB
# EarlyStopping counter: 19 out of 20
# Epoch: 323 | train_loss: 0.0030 | val_loss: 0.0034 | train_psnr: 25.37 dB | val_psnr: 26.58 dB
# EarlyStopping counter: 20 out of 20
# Early stopping
# Total training time: 5296.848 seconds
# VBox(children=(Label(value='2.018 MB of 2.018 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>total_training_time</td><td>▁</td></tr><tr><td>train_loss</td><td>█▄▄▃▃▃▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_psnr</td><td>▁▅▅▅▆▆▆▆▇▇▇▇▇▇▇█████████████████████████</td></tr><tr><td>val_loss</td><td>█▄▄▄▃▃▃▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_psnr</td><td>▁▅▅▅▆▆▆▇▇▇▇▇▇▇▆▇▇████████▇█████████▇████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>322</td></tr><tr><td>total_training_time</td><td>5296.84783</td></tr><tr><td>train_loss</td><td>0.00296</td></tr><tr><td>train_psnr</td><td>25.37336</td></tr><tr><td>val_loss</td><td>0.00339</td></tr><tr><td>val_psnr</td><td>26.57578</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">legendary-orchid-29</strong> at: <a href='https://wandb.ai/pershadmayank/SRCNN/runs/gevc1x2t' target="_blank">https://wandb.ai/pershadmayank/SRCNN/runs/gevc1x2t</a><br/>Synced 5 W&B file(s), 0 media file(s), 1 artifact file(s) and 6 other file(s)
# Find logs at: <code>./wandb/run-20240221_011216-gevc1x2t/logs</code>

# %% [markdown]
# ## 6.3 Save Results Dictionary

# %%
import pickle
import os

metrics_path = f'SRCNN/Metrics'

if not os.path.exists(metrics_path):
  os.makedirs(metrics_path)

pickle_file_path = os.path.join(metrics_path, f"metrics_{model_name}.pkl")


with open(pickle_file_path, 'wb') as file:
    pickle.dump(model_0_results, file)

print(f"Results saved to {pickle_file_path}")
# Out:
# Results saved to SRCNN/Metrics/metrics_model8_9_3_5.pkl

# %% [markdown]
# ## 6.4 Download the checkpoints and model

# %%
from google.colab import files
# !zip -r Checkpoints.zip SRCNN/Checkpoints
# !zip -r models.zip SRCNN/models
# !zip -r metrics.zip SRCNN/Metrics
files.download('Checkpoints.zip')
files.download('models.zip')
files.download('metrics.zip')
# Out:
#   adding: SRCNN/Checkpoints/ (stored 0%)
#   adding: SRCNN/Checkpoints/model8_9_3_5/ (stored 0%)
#   adding: SRCNN/Checkpoints/model8_9_3_5/epoch_225.pth (deflated 42%)
#   adding: SRCNN/Checkpoints/model8_9_3_5/epoch_300.pth (deflated 42%)
#   adding: SRCNN/Checkpoints/model8_9_3_5/epoch_150.pth (deflated 30%)
#   adding: SRCNN/Checkpoints/model8_9_3_5/epoch_75.pth (deflated 26%)
#   adding: SRCNN/Checkpoints/model8_9_3_5/epoch_0.pth (deflated 8%)
#   adding: SRCNN/models/ (stored 0%)
#   adding: SRCNN/models/model8_9_3_5.pth (deflated 42%)
#   adding: SRCNN/Metrics/ (stored 0%)
#   adding: SRCNN/Metrics/metrics_model8_9_3_5.pkl (deflated 34%)

# %%
plot_loss_curves(model_0_results)

# %% [markdown]
# # 7.0 Resuming the model training from checkpoint
#
#
# 1.  Log In into wandb
# 2.  Connet to specific project run instance using `wandb.Api()`
# 3.  Dowload the checkpoint files using `run.files()`
# 4.  Get the latest checkpoint
# 5.  Load the latest checkpoint
# 6.  Get the config.yaml file
# 7.  Parse the yaml files and the configs
# 8.  Setup the model, optmizier, loss_fn and epoch according to config
# 9.  Resume/Continue training the model

# %%
# Setup device agnostic code
device = "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cpu'

# %%
# !pip install wandb

# %%
# !export WANDB_API_KEY='0736c590933a18ad9639f49867ed1548495ded1c'

# %% [markdown]
# ## 7.1 Log In

# %%
import wandb

project_name = "SRCNN"
entity_name = "pershadmayank"

# Initialize W&B web client
api = wandb.Api()
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#  ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %% [markdown]
# ## 7.2 Connect to the specific project run

# %%
# Define the wandb entity and project
project_name = "SRCNN"  # replace with your wandb project name
entity_name = "pershadmayank"  # replace with your wandb entity
run_id = input("Enter runtime ID: ")  # replace with the run ID you want to download from

# Get the specific run
run = api.run(f"{entity_name}/{project_name}/{run_id}")
# Out:
# Enter runtime ID: yaukx79p

# %% [markdown]
# ## 7.3 Download the checkpoints

# %%
import os
import wandb

# List all files in the root directory of the run
root_files = run.files()

# Define the directory where you want to save the checkpoints
checkpoint_dir = 'Checkpoints'
if not os.path.exists(checkpoint_dir):
    os.makedirs(checkpoint_dir)

# Download the specific checkpoint files
for file in root_files:
    if file.name.startswith("model") and file.name.endswith(".pth"):
        download_path = os.path.join(checkpoint_dir, file.name)
        file.download(root=checkpoint_dir, replace=True)  # Set replace=True to overwrite existing files
        print(f"Downloaded {file.name} to {download_path}")

print("All checkpoint files have been downloaded to the specified folder.")
# Out:
# Downloaded model1_9_3_5_epoch_0.pth to Checkpoints/model1_9_3_5_epoch_0.pth
# Downloaded model1_9_3_5_epoch_100.pth to Checkpoints/model1_9_3_5_epoch_100.pth
# Downloaded model1_9_3_5_epoch_150.pth to Checkpoints/model1_9_3_5_epoch_150.pth
# Downloaded model1_9_3_5_epoch_199.pth to Checkpoints/model1_9_3_5_epoch_199.pth
# Downloaded model1_9_3_5_epoch_50.pth to Checkpoints/model1_9_3_5_epoch_50.pth
# All checkpoint files have been downloaded to the specified folder.

# %%
import re

def find_latest_checkpoint(checkpoint_files):
    # Regular expression to extract the epoch number from the filename
    epoch_regex = re.compile(r"epoch_(\d+)\.pth")

    # Dictionary to hold filename and corresponding epoch number
    checkpoints = {}

    # Iterate over the file list and extract epoch numbers
    for filename in checkpoint_files:
        match = epoch_regex.search(filename)
        if match:
            # Convert the epoch number to an integer for comparison
            epoch_num = int(match.group(1))
            checkpoints[epoch_num] = filename

    # Find the highest epoch number, which corresponds to the latest checkpoint
    latest_epoch = max(checkpoints.keys())
    latest_checkpoint = checkpoints[latest_epoch]

    return latest_epoch, latest_checkpoint

# %%
# Assuming you have the checkpoint path
latest_epoch, latest_checkpoint_path = find_latest_checkpoint(os.listdir('Checkpoints'))
latest_checkpoint_path = os.path.join('Checkpoints', latest_checkpoint_path)
latest_epoch, latest_checkpoint_path
# Out:
# (199, 'Checkpoints/model1_9_3_5_epoch_199.pth')

# %% [markdown]
# ## 7.4 Load the checkpoint

# %%
import torch

def load_checkpoint(model, optimizer, path):
    """
    Loads the checkpoint into the model and optimizer.
    """
    checkpoint = torch.load(path)
    model.load_state_dict(checkpoint['model_state_dict'])
    optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
    epoch = checkpoint['epoch']
    loss = checkpoint['loss']
    return model, optimizer, epoch, loss

# %% [markdown]
# ## 7.5 Download the config

# %%
# Download the config.yaml file
config_file = run.file("config.yaml")
config_path = "Config/config.yaml"  # specify your desired path
config_file.download(root="Config", replace=True)
# Out:
# <_io.TextIOWrapper name='Config/config.yaml' mode='r' encoding='UTF-8'>

# %%
# !pip install pyyaml
# Out:
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (6.0.1)

# %%
import yaml

# Load the configuration
with open("Config/config.yaml", 'r') as file:
    config_data = yaml.safe_load(file)

# %% [markdown]
# ## 7.6 Parse the config

# %%
# Resume the wandb run
wandb.init(project=project_name, entity=entity_name, id=run_id, resume="allow", config=config_data)
# Out:
# wandb: Currently logged in as: pershadmayank. Use `wandb login --relogin` to force relogin
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011113962000000458, max=1.0…
# Tracking run with wandb version 0.16.3
# Run data is saved locally in <code>/content/wandb/run-20240209_110612-yaukx79p</code>
# Resuming run <strong><a href='https://wandb.ai/pershadmayank/SRCNN/runs/yaukx79p' target="_blank">silvery-shadow-11</a></strong> to <a href='https://wandb.ai/pershadmayank/SRCNN' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/pershadmayank/SRCNN' target="_blank">https://wandb.ai/pershadmayank/SRCNN</a>
#  View run at <a href='https://wandb.ai/pershadmayank/SRCNN/runs/yaukx79p' target="_blank">https://wandb.ai/pershadmayank/SRCNN/runs/yaukx79p</a>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src='https://wandb.ai/pershadmayank/SRCNN/runs/yaukx79p?jupyter=true' style='border:none;width:100%;height:420px;display:none;'></iframe>

# %%
import torch

# Parsing only the relevant configuration and ignoring metadata or other non-relevant keys
config = {k: v['value'] for k, v in config_data.items() if isinstance(v, dict) and 'value' in v}
config['start_epoch'] = latest_epoch

# Now you can access the configuration values directly
# Recreate an instance of SRCNN Model using the parsed config
model_0 = SRCNNModel(input_shape=config['input_shape'],
                     hidden_units_1=config['hidden_units_1'],
                     hidden_units_2=config['hidden_units_2'],
                     kernel_sizes=config['kernel_sizes'],
                     output_shape=config['output_shape']).to(device)

# Separate parameters for different learning rates
first_two_layers_params = list(model_0.conv_block_1.parameters())
last_layer_params = list(model_0.conv_block_2.parameters())

# Setup the optimizer with learning rates from the parsed config
optimizer = torch.optim.Adam([
    {'params': first_two_layers_params, 'lr': config['learning_rate_first_two_layers']},
    {'params': last_layer_params, 'lr': config['learning_rate_last_layer']}
])

# Setup the loss function
loss_fn = custom_mse_loss

# %% [markdown]
# ## 7.5 Load the model, optimizer and loss

# %%
# Load the model and optimizer (make sure to define these before this step)
model, optimizer, start_epoch, loss = load_checkpoint(model_0, optimizer, latest_checkpoint_path)

# %% [markdown]
# ## 7.6 Resume training

# %%
EPOCHS = int(input("Epochs to train more: "))

config['end_epoch'] = int(config['start_epoch']) + EPOCHS
# Out:
# Epochs to train more: 50

# %%
# Train the model for the remaining epochs
model_0_results = train(model=model_0,
                        train_dataloader=train_dataloader_custom,
                        test_dataloader=validation_dataloader_custom,
                        optimizer=optimizer,
                        loss_fn=loss_fn,
                        path=model_name,
                        start_epoch=latest_epoch,  # Train only for the remaining epochs
                        end_epoch=latest_epoch + EPOCHS,
                        device=device,
                        checkpoint_interval=config.checkpoint_interval)

# %% [markdown]
# # 8.0 Loading Pre-Trained Model

# %%
import torch

# Setup device agnostic code
device = "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cuda'

# %%
# %%capture
# !pip install wandb

# %%
import os

# Set the API key
os.environ['WANDB_API_KEY'] = '0736c590933a18ad9639f49867ed1548495ded1c'

# %% [markdown]
# ## 8.1 Log In

# %%
import wandb

# Initialize W&B web client
api = wandb.Api()

# %% [markdown]
# ## 8.2 Connect to the specific project run

# %%
# Define the wandb entity and project
project_name = "SRCNN"  # replace with your wandb project name
entity_name = "pershadmayank"  # replace with your wandb entity
run_id = input("Enter runtime ID: ")  # replace with the run ID you want to download from

# Get the specific run
run = api.run(f"{entity_name}/{project_name}/{run_id}")
# Out:
# Enter runtime ID: gevc1x2t

# %% [markdown]
# ## 8.3 Download the config

# %%
# Download the config.yaml file
config_file = run.file("config.yaml")
config_path = "Config/config.yaml"  # specify your desired path
config_file.download(root="Config", replace=True)
# Out:
# <_io.TextIOWrapper name='Config/config.yaml' mode='r' encoding='UTF-8'>

# %%
# %%capture
# !pip install pyyaml

# %%
import yaml

# Load the configuration
with open("Config/config.yaml", 'r') as file:
    config_data = yaml.safe_load(file)

# %% [markdown]
# ## 8.4 Parse the config

# %%
# Resume the wandb run if want to retrain the model
# wandb.init(project=project_name, entity=entity_name, id=run_id, resume="allow", config=config_data)

# %%
config = {}
for k,v in config_data.items():
  if isinstance(v, dict) and 'value' in v:
    config[k] = v['value']
    # if isinstance(v['value'], dict) and 'value' in v['value']:
    #   config[k] = v['value']['value']
    #   if isinstance(v['value']['value'], dict) and 'value' in v['value']:
    #     config[k] = v['value']['value']['value']

# %%
import torch

# Now you can access the configuration values directly
# Recreate an instance of SRCNN Model using the parsed config
model = SRCNNModel(input_shape=config['input_shape'],
                     hidden_units_1=config['hidden_units_1'],
                     hidden_units_2=config['hidden_units_2'],
                     kernel_sizes=config['kernel_sizes'],
                     output_shape=config['output_shape']).to(device)

# Separate parameters for different learning rates
first_two_layers_params = list(model.conv_block_1.parameters())
last_layer_params = list(model.conv_block_2.parameters())

# Setup the optimizer with learning rates from the parsed config
optimizer = torch.optim.Adam([
    {'params': first_two_layers_params, 'lr': config['learning_rate_first_two_layers']},
    {'params': last_layer_params, 'lr': config['learning_rate_last_layer']}
])

# Setup the loss function
loss_fn = custom_mse_loss

# %%
# Get the artifact using the API
artifact = api.artifact("pershadmayank/SRCNN/SRCNNModel:v12", type="model")

# Use the artifact in your current run
run = wandb.init()
artifact_obj = run.use_artifact(artifact)

# Download the artifact's contents
artifact_dir = artifact_obj.download()
# Out:
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011113449466655665, max=1.0…
# Tracking run with wandb version 0.16.3
# Run data is saved locally in <code>/content/wandb/run-20240221_041525-1gp5oroi</code>
# Syncing run <strong><a href='https://wandb.ai/pershadmayank/uncategorized/runs/1gp5oroi' target="_blank">bright-goat-5</a></strong> to <a href='https://wandb.ai/pershadmayank/uncategorized' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/pershadmayank/uncategorized' target="_blank">https://wandb.ai/pershadmayank/uncategorized</a>
#  View run at <a href='https://wandb.ai/pershadmayank/uncategorized/runs/1gp5oroi' target="_blank">https://wandb.ai/pershadmayank/uncategorized/runs/1gp5oroi</a>
# wandb:   1 of 1 files downloaded.

# %%
import os
import glob

# Assuming artifact_dir is the directory where the artifact is downloaded
model_path = glob.glob(os.path.join(artifact_dir, "*.pth"))

if not model_path:
    raise FileNotFoundError("No .pth file found in the artifact directory.")

model_path[0]
# Out:
# '/content/artifacts/SRCNNModel:v12/model8_9_3_5.pth'

# %%
# Load the checkpoint
checkpoint = torch.load(model_path[0], map_location=device)  # or 'cuda' if using GPU

# Apply the loaded state dictionaries to the model and optimizer
model.load_state_dict(checkpoint['model_state_dict'])
optimizer.load_state_dict(checkpoint['optimizer_state_dict'])

# Move the model to the desired device
model.to(device)
# Out:
# SRCNNModel(
#   (conv_block_1): Sequential(
#     (0): Conv2d(1, 64, kernel_size=(9, 9), stride=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1))
#     (3): ReLU()
#   )
#   (conv_block_2): Sequential(
#     (0): Conv2d(32, 1, kernel_size=(5, 5), stride=(1, 1))
#   )
# )

# %% [markdown]
# # 9.0 Inference using trained Model

# %%
import torch
import torchvision.transforms as transforms
from PIL import Image

# /content/SRCNN/Data/Test/LR/baboon.bmp
# test_img_path = input("Enter Image Path: ")
test_img_path = "/content/SRCNN/Data/Test/HR/baboon.bmp"

# Convert BMP to JPEG or PNG
hr_img = Image.open(test_img_path).convert('RGB')

hr_img_ycbcr = hr_img.convert('YCbCr')

# Convert images to numpy arrays
hr_img_array = np.array(hr_img_ycbcr)

hr_img_array = modcrop(hr_img_array, scale)

# Take the y channel
y_channel = hr_img_array[:, :, 0]

test_img = generate_lr_image(y_channel, operation, scale, kernel_size, sigma)

# Convert the Y channel image to a PyTorch tensor
test_img_transform = transforms.Compose([
    transforms.ToTensor(),
])

# Convert RGB to Y channel and get Image Tensor
test_img_tensor = test_img_transform(test_img)

# Move the tensor to the designated device
test_img_tensor = test_img_tensor.to(device)

# Print out image data
print(f"Test Image Tesnor:\n {test_img_tensor}\n")
print(f"Test Image Shape: {test_img_tensor.shape}")
print(f"Test Image stype: {test_img_tensor.dtype}")
# Out:
# Test Image Tesnor:
#  tensor([[[0.6314, 0.5843, 0.4392,  ..., 0.6235, 0.6471, 0.6588],
#          [0.5843, 0.5412, 0.4078,  ..., 0.5961, 0.5961, 0.6039],
#          [0.4471, 0.4157, 0.3137,  ..., 0.5255, 0.4549, 0.4353],
#          ...,
#          [0.3373, 0.3451, 0.3647,  ..., 0.1765, 0.1686, 0.1686],
#          [0.3137, 0.3255, 0.3529,  ..., 0.1843, 0.1725, 0.1686],
#          [0.3059, 0.3176, 0.3490,  ..., 0.1882, 0.1725, 0.1686]]],
#        device='cuda:0')
#
# Test Image Shape: torch.Size([1, 480, 498])
# Test Image stype: torch.float32

# %%
test_img_tensor.shape, test_img_tensor.unsqueeze(dim=0).shape
# Out:
# (torch.Size([1, 480, 498]), torch.Size([1, 1, 480, 498]))

# %%
# Set it to evaluation mode
model.eval()
with torch.inference_mode():
  y_predicted = model(test_img_tensor.unsqueeze(dim=0).to(device))

# %%
y_predicted.shape
# Out:
# torch.Size([1, 1, 466, 484])

# %%
import numpy as np

def crop(original_img, target_height, target_width):
  """
  Crop the central region of the image to match the target height and width.
  """
  orig_height, orig_width = original_img.shape[:2]
  start_x = (orig_width - target_width) // 2
  start_y = (orig_height - target_height) // 2
  return original_img[start_y:start_y + target_height, start_x:start_x + target_width]

# %%
# test_img = test_img.convert('YCbCr')
y, Cb, Cr = hr_img_ycbcr.split()

# Process the output
y_predicted = y_predicted.squeeze().cpu().numpy() * 255
y_predicted = y_predicted.astype(np.uint8)

# # Convert Cb and Cr to numpy for cropping
# y = np.array(y).astype(np.uint8)
# Cb = np.array(Cb).astype(np.uint8)
# Cr = np.array(Cr).astype(np.uint8)

# Crop Y, Cb and Cr channels to match the predicted Y size
target_height, target_width = y_predicted.shape[:2]
y = crop(hr_img_array[:, :,  0], target_height, target_width)
Cb = crop(hr_img_array[:, :,  1], target_height, target_width)
Cr = crop(hr_img_array[:, :,  2], target_height, target_width)

# %%
import matplotlib.pyplot as plt

# Calculate the combined metrics
metrics = combined_metric(y, y_predicted.squeeze())
metrics_str = f"MSE: {metrics[0]:.2f}\n PSNR: {metrics[1]:.2f} dB\n SSIM: {metrics[2]:.2f}\n"

plt.figure(figsize=(8, 6))
plt.subplot(1, 2, 1)
plt.imshow(y, cmap="gray")
plt.title(f"Original Image\n {y.shape}", fontsize=8)
plt.xticks([])
plt.yticks([])

plt.subplot(1, 2, 2)
plt.imshow(y_predicted, cmap="gray")
plt.title(f"Predicted Image\n {y_predicted.shape}", fontsize=8)
plt.xlabel(metrics_str, fontsize=8)  # Display combined metrics here
plt.xticks([])
plt.yticks([])
plt.show()

# %%
import cv2 as cv

# Combine the cropped original channels into a YCbCr image
cropped_ycbcr = np.stack((y, Cb, Cr), axis=-1).astype(np.uint8)
predicted_ycbcr = np.stack((y_predicted.squeeze(), Cb, Cr), axis=-1).astype(np.uint8)
# Convert YCbCr to RGB
cropped_rgb = cv.cvtColor(cropped_ycbcr, cv.COLOR_YCrCb2BGR)
predicted_rgb = cv.cvtColor(predicted_ycbcr, cv.COLOR_YCrCb2BGR)

# %%
import matplotlib.pyplot as plt

# Calculate the combined metrics
metrics = combined_metric(cropped_rgb, predicted_rgb)
metrics_str = f"MSE: {metrics[0]:.2f}\n PSNR: {metrics[1]:.2f} dB\n SSIM: {metrics[2]:.2f}\n"

plt.figure(figsize=(8, 6))
plt.subplot(1, 2, 1)
plt.imshow(cropped_rgb)
plt.title(f"Original HR Image\n {cropped_rgb.shape}", fontsize=8)
plt.xticks([])
plt.yticks([])

plt.subplot(1, 2, 2)
plt.imshow(predicted_rgb)
plt.title(f"Predicted Image\n {predicted_rgb.shape}", fontsize=8)
plt.xlabel(metrics_str, fontsize=8)  # Display combined metrics here
plt.xticks([])
plt.yticks([])
plt.show()

# %% [markdown]
# **Note:** To make a prediction using the trained SRCNN model on a custom image:
#
# 1. Load the image using PIL and ensure it's in RGB format.
# 2. Convert the RGB image to YCbCr format and extract the Y channel.
# 3. Apply necessary transformations to the Y channel (e.g., resize, convert to tensor).
# 4. Add a batch dimension to the tensor to make it suitable for the model.
# 5. Set the model to evaluation mode using `model.eval()`.
# 6. Move the tensor to the same device as the model (if using GPU).
# 7. Pass the tensor through the model to get the predicted Y channel.
# 8. Resize the original Cb and Cr channels to match the predicted Y channel's dimensions (if necessary).
# 9. Merge the predicted Y channel with the resized Cb and Cr channels.
# 10. Convert the resulting YCbCr image back to RGB.
# 11. Visualize or save the resulting RGB image.
#
# Ensure that all tensors are of the correct datatype (typically `torch.float32`) and that the preprocessing steps match those used during the model's training phase.

# %%
import torch
import numpy as np
from PIL import Image
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import cv2 as cv

def pred_and_plot_image(model: torch.nn.Module, image_path: str, transform=None, plot=False, device: torch.device = torch.device('cpu')):
  # Load image and convert
  hr_img = Image.open(image_path).convert('RGB')
  hr_img_ycbcr = hr_img.convert('YCbCr')
  hr_img_array = np.array(hr_img_ycbcr)

  hr_img_array = modcrop(hr_img_array, scale)

  y_channel = hr_img_array[:, :, 0]  # Take the Y channel
  test_img = generate_lr_image(y_channel, operation, scale, kernel_size, sigma)

  if transform is None:
    transform = transforms.Compose([transforms.ToTensor()])

  test_img_tensor = transform(test_img).to(device)

  # Inference
  model.eval()
  with torch.no_grad():
      y_predicted = model(test_img_tensor.unsqueeze(0))

  # Process the output
  y_predicted = y_predicted.squeeze().cpu().numpy() * 255
  y_predicted = y_predicted.astype(np.uint8)

  # Crop original channels to match the predicted Y size
  target_height, target_width = y_predicted.shape
  y, Cb, Cr = crop(hr_img_array[:, :, 0], target_height, target_width), \
              crop(hr_img_array[:, :, 1], target_height, target_width), \
              crop(hr_img_array[:, :, 2], target_height, target_width)

  # Combine and convert for plotting
  cropped_ycbcr = np.stack((y, Cb, Cr), axis=-1).astype(np.uint8)
  predicted_ycbcr = np.stack((y_predicted, Cb, Cr), axis=-1).astype(np.uint8)
  cropped_rgb = cv.cvtColor(cropped_ycbcr, cv.COLOR_YCrCb2BGR)
  predicted_rgb = cv.cvtColor(predicted_ycbcr, cv.COLOR_YCrCb2BGR)


  if plot:
    metrics = combined_metric(cropped_rgb, predicted_rgb)
    metrics_str = f"MSE: {metrics[0]:.2f}\n PSNR: {metrics[1]:.2f} dB\n SSIM: {metrics[2]:.2f}\n"

    plt.figure(figsize=(8, 6))
    plt.subplot(1, 2, 1)
    plt.imshow(cropped_rgb)
    plt.title("Original HR Image")
    plt.xticks([])
    plt.yticks([])

    plt.subplot(1, 2, 2)
    plt.imshow(predicted_rgb)
    plt.title("Predicted Image")
    plt.xlabel(metrics_str)
    plt.xticks([])
    plt.yticks([])
    plt.show()
  return cropped_rgb, predicted_rgb

# %%
# /content/SRCNN/Data/Test/LR/lenna.bmp
# test_img_path = input("Enter Image Path: ")
test_img_path = "/content/SRCNN/Data/Test/HR/lenna.bmp"

# %%
pred_img = pred_and_plot_image(model=model,  # Replace with your model variable
                                image_path=test_img_path,  # Replace with the path to your image
                                transform=test_img_transform,  # The transformation to apply
                                device=device,  # The device (cpu or cuda)
                                plot=True)

# %%
from PIL import Image
import pandas as pd


# Initialize DataFrame to store results
results_df = pd.DataFrame(columns=['Filename', 'MSE', 'PSNR', 'SSIM'])

# Instead of using append in a loop, collect your rows in a list
rows_to_add = []

test_img_dir = "/content/SRCNN/Data/Test/HR"
for f in os.listdir(test_img_dir):

  filename = f.split('.')[0]

  image_path = os.path.join(test_img_dir, f)

  # Get the predicted image
  cropped_img, predicted_img = pred_and_plot_image(model=model,
                                      image_path=os.path.join(test_img_dir, f),
                                      transform=test_img_transform,
                                      device=device,
                                      plot=False)

  # Compute metrics
  metrics = combined_metric(cropped_img, predicted_img)

  # Append the row as a dictionary to the list
  rows_to_add.append({'Filename': filename, 'MSE': metrics[0], 'PSNR': metrics[1], 'SSIM': metrics[2]})

results_df = pd.concat([results_df, pd.DataFrame(rows_to_add)], ignore_index=True)

# %%
set5 = [1, 12, 13, 15, 16]
set5_df = results_df.iloc[set5].reset_index(drop=True)
avg_psnr =set5_df['PSNR'].mean()
print(f"Average PSNR: {avg_psnr:.2f}dB")
set5_df
# Out:
# Average PSNR: 28.67dB
#        Filename         MSE       PSNR      SSIM
# 0       bird_GT   49.951258  31.145339  0.957547
# 1       baby_GT   42.857586  31.810527  0.942953
# 2       head_GT   59.682796  30.372312  0.877014
# 3      woman_GT  125.719066  27.136792  0.923862
# 4  butterfly_GT  334.392549  22.888238  0.895513

# %%
set14_df = results_df.drop(set5).reset_index(drop=True)
avg_psnr = set14_df['PSNR'].mean()
print(f"Average PSNR: {avg_psnr:.2f}dB")
set14_df
# Out:
# Average PSNR: 25.25dB
#       Filename         MSE       PSNR      SSIM
# 0         face   59.648039  30.374842  0.876846
# 1         ppt3  999.662040  18.132272  0.834093
# 2       pepper   59.302509  30.400073  0.924708
# 3      foreman   62.135650  30.197395  0.944650
# 4      flowers  200.005565  25.120383  0.862466
# 5       bridge  305.369720  23.282544  0.747404
# 6       baboon  566.076727  20.602051  0.642452
# 7        lenna   68.398416  29.780343  0.916291
# 8        comic  547.960562  20.743311  0.757474
# 9      barbara  282.971632  23.613375  0.811292
# 10       zebra  217.411372  24.757981  0.861290
# 11         man  224.149929  24.625418  0.813755
# 12  coastguard  254.009101  24.082311  0.724441
# 13     monarch  108.084820  27.793157  0.949567
